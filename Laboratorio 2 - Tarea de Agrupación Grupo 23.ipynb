# %% [markdown]
# # Laboratorio 2 - Agrupación
#
# ### Grupo 23
# - **Estudiante 1** : Ana María Hernández Lasso
# - **Estudiante 2** : Juan Sebastián Ardila López
# - **Estudiante 3** : William Andrés Bayona Vergara

# %% [markdown]
# ## 1. Exploración de datos
#
# ### Carga del dataset
#
# Primero, cargaremos el dataset desde el archivo CSV con el fin de comprender los datos que se nos han otorgado.

# %%
import pandas as pd
import numpy as np

#Cargamos el dataset de los datos de entrenamiento
datos_senecafe = pd.read_csv("Datos_SenecaféAlpes.csv", sep=";")

#Veamos las dimensiones del dataset
filas, columnas = datos_senecafe.shape
print("Cantidad de filas:", filas)
print("Cantidad de columnas:", columnas)

#Veamos el dataframe para entender mejor los datos
datos_senecafe
# Out:
# Cantidad de filas: 14291
# Cantidad de columnas: 19
#             ID   Area   Perimetro  LongitudEjeMayor  LongitudEjeMenor  \
# 0      G006149  50836   923618.00        358.515147        181.388899
# 1      G007234  62764  1003767.00        409.207082        198.330199
# 2      G007054  59965   994266.00        389.088529        197.967275
# 3      G006619  55035      917.60        379.346822        185.390577
# 4      G013353  39324   737773.00        262.520242        191.176858
# ...        ...    ...         ...               ...               ...
# 14286  G005192  83266  1117778.00        448.473710        237.747098
# 14287  G013419  39857   755392.00        283.623668        179.430885
# 14288  G005391  90004  1156599.00        456.836383        252.353553
# 14289  G000861  38426   711412.00        246.696608        198.555756
# 14290  G007271  63628      997.39        400.784151        204.033966
#
#       RelacionAspecto  Excentricidad  AreaConvexa  DiametroEquivalente  \
# ...

# %% [markdown]
# Podemos ver que contamos con 14291 registros y 19 columnas o variables.

# %%
#Veamos las columnas y sus tipos de datos
datos_senecafe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14291 entries, 0 to 14290
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   14291 non-null  object
#  1   Area                 14291 non-null  int64
#  2   Perimetro            13054 non-null  float64
#  3   LongitudEjeMayor     13890 non-null  float64
#  4   LongitudEjeMenor     14291 non-null  float64
#  5   RelacionAspecto      13825 non-null  object
#  6   Excentricidad        13687 non-null  float64
#  7   AreaConvexa          12868 non-null  float64
#  8   DiametroEquivalente  12368 non-null  float64
#  9   Medida               14291 non-null  float64
#  10  Solidez              11985 non-null  float64
#  11  Redondez             12228 non-null  float64
#  12  Compacidad           13641 non-null  float64
#  13  FactorForma1         13172 non-null  float64
#  14  FactorForma2         13185 non-null  float64
# ...

# %% [markdown]
# En el diccionario de datos se hace referencia a 19 columnas. En efecto, en los datos compartidos este es el número de columnas existentes.

# %% [markdown]
# ### Tipos de Datos

# %%
#Según el tipo de dato podemos saber cuáles podrían llegar ser variables categóricas o numéricas, o si hay algo extraño

#Traemos las columnas de tipo object, que suelen ser texto
lista_variables_texto = datos_senecafe.select_dtypes(include=["object"]).columns

#Traemos las columnas de tipo int64, float64
lista_variables_numero = datos_senecafe.select_dtypes(include=['float64', 'int64']).columns

#Ahora podemos conocerlas mejor
print("Lista variables de texto:")
print(lista_variables_texto)
print("-------------")
print("Lista variables de número:")
print(lista_variables_numero)
print("-------------")
print("Cantidad de variables de texto:", len(lista_variables_texto))
print("Cantidad de variables de número:", len(lista_variables_numero))
# Out:
# Lista variables de texto:
# Index(['ID', 'RelacionAspecto', 'DefectoVisible', 'MétodoSecado'], dtype='object')
# -------------
# Lista variables de número:
# Index(['Area', 'Perimetro', 'LongitudEjeMayor', 'LongitudEjeMenor',
#        'Excentricidad', 'AreaConvexa', 'DiametroEquivalente', 'Medida',
#        'Solidez', 'Redondez', 'Compacidad', 'FactorForma1', 'FactorForma2',
#        'FactorForma3', 'FactorForma4'],
#       dtype='object')
# -------------
# Cantidad de variables de texto: 4
# Cantidad de variables de número: 15

# %% [markdown]
# Hemos podido ver que los nombres de las columnas presentes y el tipo de dato para cada una concuerda con la descripción dada en el diccionario de datos por la empresa. Esto nos ayuda a preparar el camino para continuar con la exploración de datos.

# %% [markdown]
# ### Visualización de la Distribución de Datos Numéricos

# %% [markdown]
# Vamos a visualizar todas las variables numeritas de tipo float por medio de boxplots, lo cual nos permitirá conocer si contamos o no con valores atípicos en el dataset.

# %%
import matplotlib.pyplot as plt


fig, axes = plt.subplots(4, 4, figsize=(20, 20))

for i, var in enumerate(lista_variables_numero):
    row = i // 4
    col = i % 4
    ax = axes[row, col]
    ax.boxplot(datos_senecafe[var].dropna())
    ax.set_title(f'Boxplot de {var}')
    ax.set_xlabel(var)


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Consideraciones sobre los datos
#
# Por ahora, como estamos en la etapa de entendimiento de los datos, dejaremos anotadas las observaciones a las que hemos llegado sobre los mismos:
#
# 1. La columna `RelaciónAspecto`, encargada de indicar si el grano es Alargado (> 1.3) o Redondeado (≤ 1.3), contiene términos como "Alargado" y "alargado", que aunque en el idioma español tienen el mismo significado y por ende darían una misma clasificación, en los datos se encuentran diferenciados por su inicial en letra minúscula o mayúscula. Más adelante debemos tratar eso, con el fin de evitar entrenar el modelo con información incoherente.
#
# 2. Esto mismo sucede con columnas que ayudan a categorizar o describir mediante términos predefinidos al grano de café, como `DefectoVisible`, que indica si el grano es Normal o Defectuoso, y `MétodoSecado`, que indica el método de procesamiento postcosecha (Natural, Lavado, Honey).
#
# 3. Muchas columnas tienen valores atípicos, más adelante tendremos que tratarlos, pues puede que algunos de los modelos dependan del cálculo de distancias (como k-means), y se vean afectados por ellos, disminuyendo así la precisión del proceso de agrupación. Adicionalmente, debemos comprobar cuáles outliers son válidos para el contexto de los granos de café, y cuáles son valores irreales o errores de digitación.

# %% [markdown]
# ### Estadisticas Descriptivas de Variables Numéricas
# Nos ayudarán a conocer mejor los datos que se nos han otorgado, identificando cómo son.

# %%
#Revisaremos las estadísticas descriptivas de variables numéricas

#Calculamos estadísticas descriptivas
estadisticas_variables_numero = datos_senecafe[lista_variables_numero].describe().T

#Agregamos la mediana
estadisticas_variables_numero['median'] = datos_senecafe[lista_variables_numero].median()

estadisticas_variables_numero
# Out:
#                        count           mean            std           min  \
# Area                 14291.0   53055.408999   29396.080372 -6.271600e+04
# Perimetro            13054.0  772986.954791  326649.281155 -1.012143e+06
# LongitudEjeMayor     13890.0     319.985592      86.378452 -4.214447e+02
# LongitudEjeMenor     14291.0     202.178613      45.494541 -2.008387e+02
# Excentricidad        13687.0       0.749977       0.099438 -8.350038e-01
# AreaConvexa          12868.0   53575.397809   29566.387814 -7.842300e+04
# DiametroEquivalente  12368.0     253.001741      60.542330 -4.484026e+02
# Medida               14291.0       0.749844       0.050774 -7.987057e-01
# Solidez              11985.0       0.986774       0.025947 -9.890416e-01
# Redondez             12228.0       0.873080       0.063237 -8.968612e-01
# Compacidad           13641.0       0.799242       0.067643 -8.439014e-01
# FactorForma1         13172.0       0.006560       0.001164 -7.982432e-03
# ...

# %% [markdown]
# - Podemos observar que todas las variables presentan valores mínimos negativos para medidas físicas de granos de café (por ejemplo, no existen valores negativos en Área, Perímetro, DiámetroEquivalente, y en general). Estos registros son probablemente errores de medición o errores de digitación y deberán tratarse más adelante, para que podamos evitar usar información distorsionada en los algoritmos de agrupación que vamos a realizar.
#
# - En general, la media y la mediana de las variables se encuentran separadas, lo que indica que sus distribuciones son asimétricas, es decir, que tienen colas largas hacia valores extremos. Esto lo veremos mejor al realizar histogramas, para conocer nuevamente cómo son los valores atípicos.

# %%
#Continuamos con algunas visualizaciones básicas para comprensión de ciertas variables del dataset
import matplotlib.pyplot as plt

columnas_graficar_1 = ['Area', 'Perimetro', 'LongitudEjeMayor', 'LongitudEjeMenor', 'Excentricidad', 'AreaConvexa']

fig, ax = plt.subplots(3, 2, figsize=(15, 15), layout='constrained')

#Aqui enumerate() sirve para recorrer la lista y al mismo tiempo obtener un contador.
for i, columna in enumerate(columnas_graficar_1):
    indice_fila = i // 2 #Dice en que fila va a estar el histograma
    indice_columna = i % 2 #Dice en que columna va a estar el histograma

    #Graficamos por ahora sin los valores nulos para evitar errores
    ax[indice_fila, indice_columna].hist(datos_senecafe[columna].dropna(), bins=40, color='skyblue', edgecolor='black')
    ax[indice_fila, indice_columna].set_title("Histograma de " + columna)
    ax[indice_fila, indice_columna].set_xlabel(columna)
    ax[indice_fila, indice_columna].set_ylabel('Frecuencia')

plt.show()

# %% [markdown]
# Esto nos permite ver y contrastar contra los valores esperados (que vienen de la descripción en el diccionario y del comportamiento normal de granos de café). Así, para las variables:
#
# - **Área:** el tamaño ocupado por un grano de café suele estar entre 25000 y 75000 píxeles de la superficie, con algunos valores que superan los 200000, los cuales son outliers. Se observan también valores negativos, que no tienen sentido físico y deben tratarse.
#
# - **Perímetro:** la longitud de un grano suele estar entre 0.6 y 1.3 millones de unidades. Aparecen valores cercanos a cero y negativos, que no son coherentes con esta medida, que es justamente no negativa.
#
# - **LongitudEjeMayor:** la longitud del eje mayor de un grano suele estar entre 200 y 450 unidades, aunque existen valores mayores a 600 que representan posibles outliers.
#
# - **LongitudEjeMenor:** la longitud del eje menor suele estar entre 150 y 250 unidades, con algunos casos mayores a 400, que son outliers. También se observan valores negativos que deben tratarse.
#
# - **Excentricidad:** la mayoría de granos presentan un valor cercano a 0.75, lo que indica formas más alargadas que circulares. Los valores negativos detectados deben tratarse, pues no se menciona esta posibilidad en el diccionario de datos. Los valores menores a 0.5 son outliers.
#
# - **ÁreaConvexa:** el área del polígono convexo más pequeño que encierra el grano suele estar entre 25000 y 100000 píxeles, con colas largas hacia valores mayores, que son outliers. También aparecen valores negativos que debemos tratar para un área.
#
# Más adelante tomaremos decisiones sobre cómo tratar estos casos, pero por ahora ha sido importante notarlos.
#
# - Los histogramas en efecto confirman distribuciones  con colas largas hacia valores altos y la presencia de registros negativos, como habíamos sospechado. Esto refuerza que deberemos hacer un preprocesamiento cuidadoso antes de aplicar algoritmos de agrupación.

# %%
#Continuamos con algunas visualizaciones básicas para comprensión de ciertas variables del dataset

columnas_graficar_1 = ['DiametroEquivalente', 'Medida', 'Solidez', 'Redondez', 'Compacidad']  

fig, ax = plt.subplots(3, 2, figsize=(15, 15), layout='constrained')

#Aqui enumerate() sirve para recorrer la lista y al mismo tiempo obtener un contador.
for i, columna in enumerate(columnas_graficar_1):
    indice_fila = i // 2 #Dice en que fila va a estar el histograma
    indice_columna = i % 2 #Dice en que columna va a estar el histograma

    #Graficamos por ahora sin los valores nulos para evitar errores
    ax[indice_fila, indice_columna].hist(datos_senecafe[columna].dropna(), bins=30, color='skyblue', edgecolor='black')
    ax[indice_fila, indice_columna].set_title("Histograma de " + columna)
    ax[indice_fila, indice_columna].set_xlabel(columna)
    ax[indice_fila, indice_columna].set_ylabel('Frecuencia')

plt.show()

# %% [markdown]
# Podemos observar que:
#
# - **DiámetroEquivalente:** la mayoría de los granos se concentran entre 200 y 300 unidades, con una cola hacia valores mayores a 400. Aparecen también valores negativos, que no son físicamente posibles en una medida de diámetro. Esto deberá tratarse más adelante.
#
# - **Medida:** la mayoría de los granos tienen valores superiores a 0.7, lo que indica que el grano ocupa de forma adecuada el área de su espacio rectangular.
#
# - **Solidez:** la distribución está muy concentrada en 1.0, lo cual significa que casi todos los granos son muy regulares en su forma.
#
# - **Redondez:** los valores se concentran entre 0.75 y 1.0, lo que indica que la mayoría de los granos presentan formas muy cercanas a ser circulares.
#
# - **Compacidad:** los valores se concentran entre 0.75 y 0.9, lo que refleja granos compactos y cerca a ser redondeados.
#
# - Los valores negativos detectados deben ser tratados, ya que no corresponden a los rangos teóricos de estas variables.

# %%
#Continuamos con algunas visualizaciones básicas para comprensión de ciertas variables del dataset
columnas_graficar_1 = ['FactorForma1', 'FactorForma2', 'FactorForma3', 'FactorForma4']

fig, ax = plt.subplots(2, 2, figsize=(10, 8), layout='constrained')

#Aqui enumerate() sirve para recorrer la lista y al mismo tiempo obtener un contador.
for i, columna in enumerate(columnas_graficar_1):
    indice_fila = i // 2 #Dice en que fila va a estar el histograma
    indice_columna = i % 2 #Dice en que columna va a estar el histograma

    #Graficamos por ahora sin los valores nulos para evitar errores
    ax[indice_fila, indice_columna].hist(datos_senecafe[columna].dropna(), bins=30, color='skyblue', edgecolor='black')
    ax[indice_fila, indice_columna].set_title("Histograma de " + columna)
    ax[indice_fila, indice_columna].set_xlabel(columna)
    ax[indice_fila, indice_columna].set_ylabel('Frecuencia')

plt.show()

# %% [markdown]
# Podemos observar lo siguiente:
#
# - **FactorForma1:** la mayoría de los valores se concentran entre 0.005 y 0.008. Aparecen valores negativos que son outliers.
#
# - **FactorForma2:** los valores se concentran entre 0.001 y 0.003. Aparecen valores negativos que son outliers.
#
# - **FactorForma3:** la mayoría de los granos se ubican con valores entre 0.5 y 0.8.
#
# - **FactorForma4:** la distribución está concentrada en 1.0.
#
#
# Se identifican valores negativos que no son coherentes con la definición de estas métricas y deben ser tratados, pues carecen de sentido acorde con el diccionario de datos.

# %% [markdown]
# ### Estadísticas Descriptivas de Variables No Numéricas
#
# Revisaremos las estadísticas descriptivas de las variables categóricas RelacionAspecto,	DefectoVisible,	MétodoSecado y de la variable de identificación ID.

# %%
#Revisar el contenido de las variables que no son numéricas, en este caso son categóricas
datos_senecafe[lista_variables_texto].describe()
# Out:
#              ID RelacionAspecto DefectoVisible MétodoSecado
# count     14291           13825          11356        13704
# unique    13611               4              2            6
# top     G006149        Alargado         Normal       Lavado
# freq          2           12047           9096         6260

# %% [markdown]
# Podemos ver que:
#
# - **ID:** Es un identificador único para cada grano. Aunque hay 13 611 valores únicos para 14 291 registros, lo cual significa que podremos encontrar duplicados más adelante.
#
# - **RelaciónAspecto:** Se identifican cuatro categorías diferentes, siendo Alargado la predominante. Sin embargo, como habíamos visto, hay valores que son distintos solo por el uso de mayúsculas/minúsculas (Alargado vs alargado). Será necesario manejar estas etiquetas antes de utilizarlas.
#
# - **DefectoVisible:** Presenta dos categorías.
# - **MétodoSecado:** Se identifican seis categorías distintas, siendo Lavado la más común (6 260 casos). Este atributo puede ser relevante para caracterizar patrones en los clusters, aunque deberemos tratar más adelante cómo va a ser usada por los algoritmos de agrupación.

# %%
#Revisaremos las estadísticas descriptivas de variables que son texto

fig, ax = plt.subplots()

#Veamos las categorias
conteo = datos_senecafe["RelacionAspecto"].value_counts()

ax.bar(conteo.index, conteo.values, color='skyblue', edgecolor='black')

ax.set_title("Distribución de RelaciónAspecto")

plt.show()

# %% [markdown]
# Esto nos confirma que existen los valores alargado y redondeado, los cuales pueden unificarse con los respectivos Alargado y Redondeado. Además, la mayoría de granos son alargados.

# %%
fig, ax = plt.subplots()

#Veamos las categorias
conteo = datos_senecafe["DefectoVisible"].value_counts()

ax.pie(conteo.values, labels=conteo.index, autopct='%1.1f%%', startangle=90)

ax.set_title("Distribución de DefectoVisible")

plt.show()

# %% [markdown]
# Todos los granos de café tienen un defecto visible normal. Nuevamente, es importante recordar que normal es equivalente a Normal, y debemos manejarlo más adelante.

# %%
fig, ax = plt.subplots()

#Veamos las categorias
conteo = datos_senecafe["MétodoSecado"].value_counts()

ax.bar(conteo.index, conteo.values, color='skyblue', edgecolor='black')

ax.set_title("Distribución de MétodoSecado")

plt.show()

# %% [markdown]
# Nuevamente, se confirma que existen equivalencias, diferenciadas en los datos únicamente por mayúsculas, pero sin distinción en su significado práctico. La mayoría de granos de café tienen el método de procesamiento lavado.

# %% [markdown]
# ### Descripción del entendimiento de datos
#
# Nos compartieron un dataset de entrenamiento con la información de 14291 granos de café, con sus determinadas características. Se identificaron 19 variables o columnas, de las cuales podemos llegar a la siguiente información:
#
# 1. Características geométricas básicas del grano: describen cómo es el espacio ocupado por el grano de café. Incluye variables como Área, Perímetro, Longitud del Eje Mayor, Longitud del Eje Menor, Área Convexa y Diámetro Equivalente, que describen directamente el tamaño y la forma física de cada grano.
#
# 2. Factores específicos del grano: reflejan qué tan alargado, compacto o circular es un grano, así como la estética general del mismo y lo diferencian e identifican de los demás granos. Incluye columnas como Relación de Aspecto, Excentricidad, Medida, Solidez, Redondez, Compacidad, ID, los Factores de Forma 1, 2, 3 y 4, Defecto Visible y Método de Secado
#
# Además, identificamos:
# - Tres variables categóricas: 'RelacionAspecto' (Alargado, Redondeado), 'DefectoVisible' (Normal, Defectuoso) y 'MetodoSecado' (Natural, Lavado, Honey).
#
# - Quince variables numéricas: 'Area', 'Perimetro', 'LongitudEjeMayor', 'LongitudEjeMenor' 'Excentricidad', 'AreaConvexa', 'DiametroEquivalente', 'Medida', 'Solidez', 'Redondez', 'Compacidad', 'FactorForma1', 'FactorForma2', 'FactorForma3' y 'FactorForma4.
#
# ### Interpretación de visualización de variables categóricas:
# - Las tres variables categóricas tienen categorías equivalentes, únicamente separadas por la manera en que se han escrito (mayúsculas/minúsculas). Por ejemplo, Alargado es equivalente a alargado. La única diferencia radica en su escritura.
#
# - Los granos de café, según los diagramas realizados, suelen ser lavados, alargados y normales.
#
# ### Interpretación de visualización y estadísticas de variables numéricas:
# Gracias a las estadísticas descriptivas y los histogramas podemos ver que:
#
# - Las medidas, tales como perímetro, área o las longitudes de los ejes tienen valores negativos, o valores muy superiores (outliers, pues son pocos casos particulares, que debemos tratar más adelante).
#
# - Variables como excentricidad, solidez, redondez y compacidad se distribuyen en los rangos esperados (cercanos a 0.7–1), aunque también se detectan registros negativos incoherentes, que hay que decidir cómo manejar.

# %% [markdown]
# ## 2. Análisis de calidad de los datos
# Revisamos las dimensiones de calidad: unicidad, completitud, consistencia, validez.

# %% [markdown]
# ### Completitud: revisar valores nulos

# %%
#Vemos cuántos nulos hay por columna
nulos = datos_senecafe.isnull().sum()

print("Cantidad de nulos por columna")
#Ordenamos los nulos de mayor a menor
nulos = nulos.sort_values(ascending=False)
display(nulos)

print("Porcentaje de nulos por columna")
# Cálculo de porcentaje de valores nulos por columna
(((nulos/datos_senecafe.shape[0]))* 100).sort_values(ascending=False)
# Out:
# Cantidad de nulos por columna
# DefectoVisible         2935
# Solidez                2306
# Redondez               2063
# DiametroEquivalente    1923
# AreaConvexa            1423
# Perimetro              1237
# FactorForma4           1159
# FactorForma1           1119
# FactorForma2           1106
# Compacidad              650
# Excentricidad           604
# MétodoSecado            587
# FactorForma3            478
# RelacionAspecto         466
# LongitudEjeMayor        401
# ID                        0
# Area                      0
# LongitudEjeMenor          0
# Medida                    0
# dtype: int64
# Porcentaje de nulos por columna
# DefectoVisible         20.537401
# Solidez                16.136030
# Redondez               14.435659
# DiametroEquivalente    13.456021
# AreaConvexa             9.957316
# Perimetro               8.655797
# FactorForma4            8.109999
# FactorForma1            7.830103
# FactorForma2            7.739137
# ...

# %%
#Hacemos el mapa de valores nulos
#Los valores nulos se encuentran en amarillo.
import seaborn as sns 
plt.figure(figsize=(10, 6))
sns.heatmap(datos_senecafe.isnull(), cbar=False, yticklabels=False, cmap='viridis')
plt.title('Mapa de valores nulos')
plt.show()

# %% [markdown]
# Podemos observar que hay 15 columnas que contienen valores nulos, donde DefectoVisible es la que tiene mayor cantidad de nulos (20.53%, es decir, 2935 registros con esa variable nula), mientras que LongitudEjeMayor tiene la menor cantidad de nulos (3.26%, es decir, 401 registros con esa variable nula). Más adelante debemos decidir cómo tratar esto, pues entrenar a los modelos sobre un dataset con nulos podría llegar a causar que se oculten patrones que, en realidad, podrían ser relevantes al momento de realizar el proceso de agrupación. Eventualmente podrían afectar el correcto procesamiento de los datos.

# %% [markdown]
# ### Unicidad: revisar filas duplicadas

# %%
#Revisamos las filas duplicadas completas
num_duplicados = datos_senecafe.duplicated().sum()
print("Número de filas duplicadas completas:", num_duplicados)

#Revisamos las filas duplicadas parciales por Jugador, Posición y Día del partido
variables_para_duplicados = ['ID']

print("-----")
duplicados_parciales = datos_senecafe.duplicated(subset=variables_para_duplicados, keep=False)
num_duplicados_parciales = duplicados_parciales.sum()
print("Número de duplicados parciales (según ID del grano de café):", num_duplicados_parciales)

print("-----")
print("Ejemplo de un duplicado: ")

#Detectar IDs duplicados
ids_duplicados = datos_senecafe[datos_senecafe["ID"].duplicated()]["ID"].unique()

#Queremos, por ejemplo, ver todas las filas del primer ID duplicado
ejemplo = datos_senecafe[datos_senecafe["ID"] == ids_duplicados[0]]
display(ejemplo)

# Mostrar algunos ejemplos
print("-----")
print("Ejemplos de duplicados parciales:")
display(datos_senecafe[duplicados_parciales].head(10))
# Out:
# Número de filas duplicadas completas: 461
# -----
# Número de duplicados parciales (según ID del grano de café): 1360
# -----
# Ejemplo de un duplicado:
#           ID   Area  Perimetro  LongitudEjeMayor  LongitudEjeMenor  \
# 126  G001698  44524   758387.0        258.916322        219.129976
# 384  G001698  44524   758387.0        258.916322        219.129976
#
#     RelacionAspecto  Excentricidad  AreaConvexa  DiametroEquivalente  \
# 126      Redondeado            NaN      44860.0           238.096026
# 384      Redondeado            NaN      44860.0           238.096026
#
#        Medida  Solidez  Redondez  Compacidad  FactorForma1  FactorForma2  \
# 126  0.782977      NaN  0.972797    0.919587      0.005815      0.002565
# 384  0.782977      NaN  0.972797    0.919587      0.005815      0.002565
#
#      FactorForma3  FactorForma4 DefectoVisible MétodoSecado
# 126       0.84564      0.999178         Normal       Lavado
# ...

# %% [markdown]
# Vemos que hay 461 registros duplicador por completo y 1360 duplicados parciales por ID del grano de café, que se supone es único (según el diccionario de datos). Además, se puede repetir varias veces el ID de un grano de café, por lo que podemos tener diferente información de un mismo grano de café. Este puede ser un duplicado parcial o total. Así, no hay unicidad total en el dataset por ahora, y debemos hacer manejo de esto para mantener coherencia sobre los granos y sus datos, pues de otro modo los algoritmos podrían darle mucho peso a aquellos registros que tienen repetición, y generar un sesgo artificial al momento de agrupar.

# %% [markdown]
# ### Validez: revisar reglas de negocio, formatos y restricciones

# %%
#Ninguna de las variables de este dataset debería admitir valores negativos en condiciones normales.

#Algunas variables deberian estar entre 0 y 1, no tomar otros valores por definición
variables_rango_cero_uno = ["Excentricidad", "Medida", "Solidez", "Redondez", "Compacidad", "FactorForma1", "FactorForma2", "FactorForma3", "FactorForma4"]

print("Revisión de valores negativos\n")
#Revisamos las que deberian ser no negativas
for columna in lista_variables_numero:
    num_invalidos = (datos_senecafe[columna] < 0).sum()
    print(columna + ": " + str(num_invalidos) + " valores negativos")

print("-----")

print("Revisión de valores que deberían ser >0 y <1 \n")
#Revisamos las que deberian estar en rango
for columna in variables_rango_cero_uno:
    num_invalidos = ((datos_senecafe[columna] < 0) | (datos_senecafe[columna] > 1)).sum()
    print(columna + ": " + str(num_invalidos) + " valores fuera de rango")
# Out:
# Revisión de valores negativos
#
# Area: 3 valores negativos
# Perimetro: 6 valores negativos
# LongitudEjeMayor: 3 valores negativos
# LongitudEjeMenor: 4 valores negativos
# Excentricidad: 9 valores negativos
# AreaConvexa: 6 valores negativos
# DiametroEquivalente: 7 valores negativos
# Medida: 1 valores negativos
# Solidez: 2 valores negativos
# Redondez: 2 valores negativos
# Compacidad: 4 valores negativos
# FactorForma1: 6 valores negativos
# FactorForma2: 7 valores negativos
# FactorForma3: 3 valores negativos
# FactorForma4: 5 valores negativos
# -----
# Revisión de valores que deberían ser >0 y <1
#
# Excentricidad: 9 valores fuera de rango
# Medida: 1 valores fuera de rango
# Solidez: 2 valores fuera de rango
# Redondez: 2 valores fuera de rango
# Compacidad: 4 valores fuera de rango
# FactorForma1: 6 valores fuera de rango
# FactorForma2: 7 valores fuera de rango
# FactorForma3: 3 valores fuera de rango
# FactorForma4: 5 valores fuera de rango

# %% [markdown]
# Confirmamos la existencia de valores negativos y fuera de rango para variables que no deberían tenerlos. Esto deberá tratarse más adelante.

# %%
#Nuevamente, veamos las opciones en las columnas categóricas
print("Valores únicos en RelacionAspecto:", datos_senecafe["RelacionAspecto"].unique())
print("Valores únicos en DefectoVisible:", datos_senecafe["DefectoVisible"].unique())
print("Valores únicos en MétodoSecado:", datos_senecafe["MétodoSecado"].unique())
# Out:
# Valores únicos en RelacionAspecto: ['alargado' 'Alargado' 'Redondeado' 'redondeado' nan]
# Valores únicos en DefectoVisible: ['Normal' nan 'normal']
# Valores únicos en MétodoSecado: ['Lavado' 'Natural' 'lavado' nan 'natural' 'Honey' 'honey']

# %% [markdown]
# Hay valores equivalentes para una misma categoría, diferenciados por la ortografía. Hay que tratarlo más adelante.

# %% [markdown]
# ### Consistencia: revisar incoherencias entre datos

# %%
#En teoría, el Area debería ser menor o igual al Área convexa, que cubre el área del grano
inconsistencias_area = (datos_senecafe["Area"] > datos_senecafe["AreaConvexa"]).sum()
print("Filas con Área mayor que ÁreaConvexa:", inconsistencias_area)
# Out:
# Filas con Área mayor que ÁreaConvexa: 6

# %% [markdown]
# Aunque se supone que el Área convexa es igual o mayor al Área, hay algunos casos que no cumplen con esta definición. Hay que tratarlos.

# %%
#En teoría, LongitudEjeMayor ≥ LongitudEjeMayor, por su definicion
inconsistencias_longitud = (datos_senecafe["LongitudEjeMayor"] < datos_senecafe["LongitudEjeMayor"]).sum()
print("Filas con LongitudEjeMayor < LongitudEjeMayor:", inconsistencias_area)
# Out:
# Filas con LongitudEjeMayor < LongitudEjeMayor: 6

# %% [markdown]
# Vemos que hay seis casos que tienen LongitudEjeMayor < LongitudEjeMayor. Hay que tratarlos.

# %% [markdown]
# ## 3. Enfoque analítico
#
# Se solicita la aplicación de técnicas de agrupación para identificar patrones morfológicos que permitan caracterizar las distintas variedades de café. Así:
#
# - **Tipo de analítica**: Analítica descriptiva, ya que corresponde a cómo son los datos, qué grupos de granos de café se pueden identificar.
#
# - **Tipo de aprendizaje**: No supervisado, ya que trabajamos con un conjunto de datos de granos sin etiquetas o categorías predefinidas para ellos. Los modelos van a buscar patrones sin decirles de antemano qué clases de grano existen o cuántos tipos de patrón hay para ellos.
#
# - **Tipo de tarea supervisada**: Clustering o Agrupación por Similitud, porque el objetivo es detectar grupos naturales de granos morfológicamente similares. No clasificamos en clases previamente definidas, y no estimamos un valor.

# %% [markdown]
# ## 4. Preselección de variables
#
# Por el momento, podemos decir que la variable ID no resulta útil para reconocer patrones y hacer clustering de los granos, ya que corresponde únicamente a un identificador interno y no aporta información morfológica, por lo cual podemos quitarla. Esto lo haremos más adelante, luego de tratar los duplicados por ID.

# %% [markdown]
# ## 5. Preparación y limpieza de los datos

# %% [markdown]
# ### Manejo de duplicados completos
#
# Dejaremos solo un registro único, con el fin de evitar crear sesgos artificiales.

# %%
#Contamos registros duplicados completos
duplicados = datos_senecafe.duplicated().sum()
print("Número de filas duplicadas:", duplicados)

#Eliminamos duplicados, dejamos solo uno
datos_senecafe = datos_senecafe.drop_duplicates()

#Verificamos de nuevo
print("Número de filas duplicadas después de eliminar duplicados completos:", datos_senecafe.duplicated().sum())
print("Cantidad de filas finales:", datos_senecafe.shape[0])
# Out:
# Número de filas duplicadas: 461
# Número de filas duplicadas después de eliminar duplicados completos: 0
# Cantidad de filas finales: 13830

# %% [markdown]
# ### Manejo de duplicados parciales (IDs repetidos)
#
# Elegimos dejar la primera aparición de un grano de café para que, en efecto, los ID sean únicos. Además, decidimos conservar solo la primera ocurrencia del ID ya que los duplicados parciales no aportan información adicional sino ruido

# %%
#Contar IDs duplicados parciales por ID despues de borrar duplicados completos
duplicados_id = datos_senecafe['ID'].duplicated().sum()
print("Duplicados según ID encontrados:", duplicados_id)

#Dejamos el primer registro
datos_senecafe = datos_senecafe.drop_duplicates(subset=['ID'], keep='first')

print("Cantidad de filas después de limpiar duplicados por ID:", datos_senecafe.shape[0])
# Out:
# Duplicados según ID encontrados: 219
# Cantidad de filas después de limpiar duplicados por ID: 13611

# %% [markdown]
# Con este proceso garantizamos que el dataset mantenga la unicidad de cada grano y reducimos el riesgo de que el clustering detecte patrones sesgados por registros repetidos

# %% [markdown]
# ### Manejo de nulos
#
# Variables numéricas con pocos valores nulos (menos del 15% de los registros totales o datos), como LongitudEjeMayor, DiámetroEquivalente, ÁreaConvexa, Perímetro, FactorForma1, FactorForma2, FactorForma3, FactorForma4, Excentricidad y Compacidad, así como variables categóricas como RelacionAspecto y MétodoSecado , permiten aplicar imputación en lugar de eliminar registros.
#
# Dado que el dataset cuenta con 13.611 observaciones, la proporción de nulos es baja, lo que hace viable imputar sin comprometer de manera significativa la calidad de los datos. Esta estrategia evita la pérdida de registros y reduce el riesgo de distorsionar los resultados del análisis. Básicamente, dado que los porcentajes de nulos en las variables son bajos, no es necesario eliminar registros completos. Imputar mantiene la mayor parte de la información disponible.
#
#
# - La media puede distorsionarse porque, como vimos, hay bastantes outliers en las variables. De ese modo, la mediana es más robusta, pues refleja el valor central de las distribuciones.

# %%
#Imputación con mediana para las variables numéricas
num_cols = ['LongitudEjeMayor', 'Excentricidad', 'Compacidad', 'FactorForma3', 
'DiametroEquivalente', 'AreaConvexa', 'Perimetro', 'FactorForma1', 'FactorForma2', 'FactorForma4']

print("Nulos en numéricas antes de imputar:")
print(datos_senecafe[num_cols].isna().sum())
print("")

for col in num_cols:
    datos_senecafe[col] = datos_senecafe[col].fillna(datos_senecafe[col].median())

print("Nulos en numéricas después de imputar:")
print(datos_senecafe[num_cols].isna().sum())
# Out:
# Nulos en numéricas antes de imputar:
# LongitudEjeMayor        385
# Excentricidad           564
# Compacidad              627
# FactorForma3            455
# DiametroEquivalente    1825
# AreaConvexa            1365
# Perimetro              1182
# FactorForma1           1069
# FactorForma2           1039
# FactorForma4           1104
# dtype: int64
#
# Nulos en numéricas después de imputar:
# LongitudEjeMayor       0
# Excentricidad          0
# Compacidad             0
# FactorForma3           0
# DiametroEquivalente    0
# AreaConvexa            0
# Perimetro              0
# FactorForma1           0
# FactorForma2           0
# FactorForma4           0
# dtype: int64

# %% [markdown]
# - Para las variables categóricas, emplearemos la moda para imputar, pues no tiene sentido calcular un promedio o mediana, ya que no hay un orden numérico.

# %%
#Imputación con moda para variables categóricas
cat_cols = ['MétodoSecado']

print("\nNulos en categóricas antes de imputar:")
print(datos_senecafe[cat_cols].isna().sum())

for col in cat_cols:
    moda = datos_senecafe[col].mode()[0]
    datos_senecafe[col] = datos_senecafe[col].fillna(moda)


print("\nNulos en categóricas después de imputar:")
print(datos_senecafe[cat_cols].isna().sum())
# Out:
# Nulos en categóricas antes de imputar:
# MétodoSecado    558
# dtype: int64
#
# Nulos en categóricas después de imputar:
# MétodoSecado    0
# dtype: int64

# %% [markdown]
# Ahora, variables como RelacionAspecto, Redondez y Solidez se pueden derivar calculándolas mediante otras variables que son o ya conocidas, o han sido imputadas.

# %%
mas_nulos_cols = ['Solidez', 'Redondez']
print(datos_senecafe[mas_nulos_cols].isna().sum())
# Out:
# Solidez     2185
# Redondez    1976
# dtype: int64

# %%
#Revisar nulos antes
print("Nulos en RelacionAspecto antes de derivar:", datos_senecafe['Solidez'].isna().sum())
print("Nulos en Solidez antes de derivar:", datos_senecafe['Solidez'].isna().sum())
print("Nulos en Redondez antes de derivar:", datos_senecafe['Redondez'].isna().sum())

#Calcular RelacionAspecto_num solo para nulos
datos_senecafe.loc[datos_senecafe["RelacionAspecto"].isna(), "RelacionAspecto_num"] = (
    datos_senecafe["LongitudEjeMayor"] / datos_senecafe["LongitudEjeMenor"]
)

#Clasificación alargado/redondeado, pero solo en nulos
datos_senecafe.loc[datos_senecafe["RelacionAspecto"].isna(), "RelacionAspecto"] = (
    datos_senecafe["RelacionAspecto_num"]
    .apply(lambda x: "alargado" if x > 1.3 else "redondeado")
)

#Calcular Solidez solo donde haya nulos
datos_senecafe.loc[datos_senecafe["Solidez"].isna(), "Solidez"] = (
    datos_senecafe["Area"] / datos_senecafe["AreaConvexa"]
)

#Calcular Redondez solo donde haya nulos
datos_senecafe.loc[datos_senecafe["Redondez"].isna(), "Redondez"] = (
    (4 * np.pi * datos_senecafe["Area"]) / (datos_senecafe["Perimetro"]**2)
)

#Revisar nulos después
print("Nulos en Solidez después de derivar:", datos_senecafe['Solidez'].isna().sum())
print("Nulos en Redondez después de derivar:", datos_senecafe['Redondez'].isna().sum())
print("Nulos en RelacionAspecto después de derivar:", datos_senecafe['RelacionAspecto'].isna().sum())


#Por ultimo, ya podemos quitar RelacionAspecto_num, que era una casilla hecha solo para nulos mientras derivabamos
datos_senecafe = datos_senecafe.drop(columns=['RelacionAspecto_num'])
# Out:
# Nulos en RelacionAspecto antes de derivar: 2185
# Nulos en Solidez antes de derivar: 2185
# Nulos en Redondez antes de derivar: 1976
# Nulos en Solidez después de derivar: 0
# Nulos en Redondez después de derivar: 0
# Nulos en RelacionAspecto después de derivar: 0

# %% [markdown]
# Finalmente, se encuentra la variable DefectoVisible:
#
# - DefectoVisible tiene más del 15% de registros del dataset con valores nulos en esta columna. Además, no es una variable que ayude al objetivo del clustering, que es ver patrones en la caracterización morfológica de un grano; en cambio, es más una etiqueta de calidad hecha al ojo, pues en el diccionario de datos se menciona que permite diferenciar entre granos sanos normales y granos con defectos visibles (Normal, Defectuoso). Esto se puede obviar, pues eventualmente podrá concentrarse en características más precisas. De esta forma, la decisión es eliminar esta columna o variable.

# %%
#Eliminamos la columna DefectoVisible
datos_senecafe = datos_senecafe.drop(columns=['DefectoVisible'])

#Verificamos que en efecto ya no esté en el dataset
print(datos_senecafe.columns)

datos_senecafe.info()
# Out:
# Index(['ID', 'Area', 'Perimetro', 'LongitudEjeMayor', 'LongitudEjeMenor',
#        'RelacionAspecto', 'Excentricidad', 'AreaConvexa',
#        'DiametroEquivalente', 'Medida', 'Solidez', 'Redondez', 'Compacidad',
#        'FactorForma1', 'FactorForma2', 'FactorForma3', 'FactorForma4',
#        'MétodoSecado'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 13611 entries, 0 to 14290
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   13611 non-null  object
#  1   Area                 13611 non-null  int64
#  2   Perimetro            13611 non-null  float64
#  3   LongitudEjeMayor     13611 non-null  float64
#  4   LongitudEjeMenor     13611 non-null  float64
#  5   RelacionAspecto      13611 non-null  object
#  6   Excentricidad        13611 non-null  float64
#  7   AreaConvexa          13611 non-null  float64
# ...

# %% [markdown]
# Revisemos que no existan nulos ahora:

# %%
print("Nulos:")
print(datos_senecafe.isna().sum())
# Out:
# Nulos:
# ID                     0
# Area                   0
# Perimetro              0
# LongitudEjeMayor       0
# LongitudEjeMenor       0
# RelacionAspecto        0
# Excentricidad          0
# AreaConvexa            0
# DiametroEquivalente    0
# Medida                 0
# Solidez                0
# Redondez               0
# Compacidad             0
# FactorForma1           0
# FactorForma2           0
# FactorForma3           0
# FactorForma4           0
# MétodoSecado           0
# dtype: int64

# %% [markdown]
# ### Manejo de valores negativos
#
# En vista de que los registros con valores negativos en columnas que no deberían admitirlo son pocos en comparación con el total de registros, podemos borrar los registros con esta condición e igual tener un número considerable de registros. Dado que la cantidad de registros afectados es baja en comparación con el total, la estrategia que elegimos es eliminar estas filas para asegurar la validez de las variables  y evitar distorsiones.

# %%
#Antes
print("Filas antes:", datos_senecafe.shape[0])

#Filtrar las validas
datos_senecafe = datos_senecafe[(datos_senecafe[lista_variables_numero] >= 0).all(axis=1)]

#Después
print("Filas después:", datos_senecafe.shape[0])
# Out:
# Filas antes: 13611
# Filas después: 13548

# %% [markdown]
# ### Manejo de valores fuera del rango válido [0,1]
#
# Los registros con valores fuera del rango en columnas que no deberían admitirlo son pocos en comparación con el total de registros, podemos borrar los registros con esta condición e igual tener un número considerable de registros, sin afectar la representatividad.

# %%
#Antes
print("Filas antes:", datos_senecafe.shape[0])

#Filtrar las validas
datos_senecafe = datos_senecafe[(datos_senecafe[variables_rango_cero_uno] >= 0).all(axis=1) &
                                (datos_senecafe[variables_rango_cero_uno] <= 1).all(axis=1)]

#Después
print("Filas después:", datos_senecafe.shape[0])
# Out:
# Filas antes: 13548
# Filas después: 13452

# %% [markdown]
# ### Manejo de registros que no cumplen con Area <= al Área convexa
#
# Los registros con valores inconsistentes en columnas que no deberían admitirlo son pocos en comparación con el total de registros, podemos borrar los registros con esta condición e igual tener un número considerable de registros.

# %%
# Filtrar solo las filas válidas: Área <= ÁreaConvexa
print("Filas antes de filtrar válidos:", datos_senecafe.shape[0])

datos_senecafe = datos_senecafe[datos_senecafe['Area'] <= datos_senecafe['AreaConvexa']]

print("Filas después de filtrar válidos:", datos_senecafe.shape[0])
# Out:
# Filas antes de filtrar válidos: 13452
# Filas después de filtrar válidos: 12858

# %% [markdown]
# ### Manejo de registos que no cumplen con LongitudEjeMayor ≥ LongitudEjeMayor
#
# Por definición geométrica, la longitud del eje mayor debe ser igual o superior a la del eje menor. Sin embargo, pueden existir registros en el dataset que violen esta condición. Estos casos contradicen la lógica de los ejes principales de un grano. De esa manera, hemos decidido eliminarlos, ya que son pocos en relación con el total de observaciones y mantenerlos introduciría ruido.

# %%
# Manejo de registros que no cumplen con LongitudEjeMayor >= LongitudEjeMenor
print("Filas antes de filtrar válidos:", datos_senecafe.shape[0])

# Filtrar solo las filas válidas: LongitudEjeMayor >= LongitudEjeMenor
datos_senecafe = datos_senecafe[datos_senecafe['LongitudEjeMayor'] >= datos_senecafe['LongitudEjeMenor']]

print("Filas después de filtrar válidos:", datos_senecafe.shape[0])
# Out:
# Filas antes de filtrar válidos: 12858
# Filas después de filtrar válidos: 12841

# %% [markdown]
# ### Mapeo de minúsculas y mayúsculas
#
# Para garantizar consistencia en los datos, convertiremos todos los valores a minúsculas y eliminaremos posibles espacios extra. De esta manera, cada categoría queda unificada bajo una misma representación (sin distinguir en mayúsculas o minúsculas), evitando duplicidad de clases y asegurando resultados confiables. Lo haremos con las dos variables categóricas que nos quedan.

# %%
columnas_categoricas = ["MétodoSecado", "RelacionAspecto"]

#Convertir a minúsculas y quitar espacios extra
for columna in columnas_categoricas:
    datos_senecafe[columna] = datos_senecafe[columna].str.strip().str.lower()

#Verificar valores únicos de cada categórica
for columna in columnas_categoricas:
    print("Columna", columna)
    print(datos_senecafe[columna].unique())
# Out:
# Columna MétodoSecado
# ['natural' 'lavado' 'honey']
# Columna RelacionAspecto
# ['alargado' 'redondeado']

# %%
display(datos_senecafe["RelacionAspecto"].value_counts())
display(datos_senecafe["MétodoSecado"].value_counts())
# Out:
# RelacionAspecto
# alargado      11157
# redondeado     1684
# Name: count, dtype: int64
# MétodoSecado
# lavado     7554
# natural    5212
# honey        75
# Name: count, dtype: int64

# %% [markdown]
# ### Manejo de Outliers
#
# Dado que la existencia de Outliers pueden distorsionar las distancias y generar ruido dentro dentro de los modelos, procederemos a eliminarlos por medio de la regla del rango intercuatilico (IQR), es decir el tamaño del rango donde se encuentran el 50% de los datos (Definido a través de la diferencia entre el tercer y primer cuartil). Este metodo permite encontrar a los datos que estan demasiado lejos del rango central de datos .
#
# - Se utilizó el método IQR (rango intercuartílico) porque permite identificar valores que están demasiado alejados del rango central de los datos, lo cual reduce ruido. Por ejemplo, podría afectar el re-cálculo de centroides en k-means.

# %%
# Identificar y eliminar outliers usando el método IQR (Interquartile Range)
print("Dimensiones originales del dataset:", datos_senecafe.shape)

# Crear una copia del dataframe para trabajar
datos_sin_outliers = datos_senecafe.copy()
filas_originales = datos_sin_outliers.shape[0]

# Aplicar el método IQR a cada variable numérica
for columna in lista_variables_numero:
    # Saltamos si la columna tiene valores nulos
    if datos_sin_outliers[columna].isna().sum() > 0:
        continue
        
    # Calculamos Q1 y Q3
    Q1 = datos_sin_outliers[columna].quantile(0.25)
    Q3 = datos_sin_outliers[columna].quantile(0.75)
    
    # Calculamos el rango intercuartílico (IQR)
    IQR = Q3 - Q1
    
    # Definimos los límites para considerar outliers (usando 1.5*IQR)
    limite_inferior = Q1 - 1.5 * IQR
    limite_superior = Q3 + 1.5 * IQR
    
    # Filtramos los outliers
    datos_sin_outliers = datos_sin_outliers[
        (datos_sin_outliers[columna] >= limite_inferior) | 
        (datos_sin_outliers[columna].isna()) &
        (datos_sin_outliers[columna] <= limite_superior) | 
        (datos_sin_outliers[columna].isna())
    ]

filas_finales = datos_sin_outliers.shape[0]
filas_eliminadas = filas_originales - filas_finales

print(f"Se eliminaron {filas_eliminadas} filas con outliers")
print(f"Dimensiones después de eliminar outliers: {datos_sin_outliers.shape}")

# Reemplazamos el dataframe original con el limpio
datos_senecafe = datos_sin_outliers
# Out:
# Dimensiones originales del dataset: (12841, 18)
# Se eliminaron 5278 filas con outliers
# Dimensiones después de eliminar outliers: (7563, 18)

# %% [markdown]
# Aunque el IQR eliminó una cantidad considerable de registros, se decidió mantener para asegurar que los outliers no distorsionen el análisis. De igual manera, el dataset resultante sigue siendo suficientemente grande (7563 observaciones) para el análisis. Tuvimos un balance adecuado entre limpieza de datos y preservación de información realmente útil.

# %% [markdown]
# #### Preselección de variables: Iteración
# El objetivo es identificar patrones morfológicos, es decir relacionados a la forma de las semillas de café, que se puede describir a partir de variables de forma, tamaño o, en general de su físico. Por ello:
#
# * ID: hemos mencionado que no es útil para la agrupación, ya que solo identifica a cada semilla, sin aportar a la descripción de su morfología.
#
# * MetodoSecado: no es útil para la agrupación, puesto que describe el proceso o método de la postcosecha (acorde con el diccionario de datos), sin aportar a la descripción de su morfología.
#
# * RelacionAspecto: no es útil para la agrupación, ya que según el diccionario de datos es la razón LongitudEjeMayor / LongitudEjeMenor. Así, podemos trabajar con esas variables de por sí en los modelos a construir, sin omitir información relevante.
#
# * Solidez y Redondez (derivadas): pueden eliminarse porque se calculan a partir de variables base ya incluidas (Área, ÁreaConvexa, Perímetro). Así, podemos trabajar con esas variables de por sí en los modelos a construir, sin omitir información relevante.
#
# De ese modo, podemos eliminarlas:

# %%
columnas_eliminar = ["ID", "MétodoSecado", "RelacionAspecto", "Solidez", "Redondez"]

print("Columnas antes:", datos_senecafe.shape[1])

datos_senecafe = datos_senecafe.drop(columns=columnas_eliminar)

print("Columnas después:", datos_senecafe.shape[1])
# Out:
# Columnas antes: 18
# Columnas después: 13

# %%
datos_senecafe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7563 entries, 2 to 14289
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Area                 7563 non-null   int64
#  1   Perimetro            7563 non-null   float64
#  2   LongitudEjeMayor     7563 non-null   float64
#  3   LongitudEjeMenor     7563 non-null   float64
#  4   Excentricidad        7563 non-null   float64
#  5   AreaConvexa          7563 non-null   float64
#  6   DiametroEquivalente  7563 non-null   float64
#  7   Medida               7563 non-null   float64
#  8   Compacidad           7563 non-null   float64
#  9   FactorForma1         7563 non-null   float64
#  10  FactorForma2         7563 non-null   float64
#  11  FactorForma3         7563 non-null   float64
#  12  FactorForma4         7563 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 827.2 KB

# %% [markdown]
# ### One Hot Encoding o Label Encoding
# No se usan porque ya no tenemos variables categóricas, así los modelos solo trabajan con variables numéricas, que no se deben transformar.

# %% [markdown]
# ### Normalización
#
# En algunos algoritmos de agrupación, como k-means o DBSCAN, se miden distancias entre puntos. Es muy importante recordar que si una variable tiene valores muy grandes, y otra valores muy pequeños, la distancia se ve dominada por la variable con valores grandes, casi ignorando la de valores pequeños. Por eso, se hace necesario aplicar estandarización o normalización.
#
# Elegimos usar normalización MinMax, que transforma cada variable para que sus valores queden dentro del rango [0,1]. En este caso, resulta útil porque tenemos variables con escalas muy diferentes. Por ejemplo, la excentricidad se mide en decimales, pues sus valores están entre 0 y 1; mientras que el área puede alcanzar valores de hasta 254616 unidades cuadradas.
#
# Con la normalización MinMax, todas las variables quedan en la misma escala sin modificar la forma de sus distribuciones, lo cual mejora que se puedan comparar y ayuda a los algoritmos a ser más efectivos.

# %%
from sklearn.preprocessing import MinMaxScaler

#Objeto para que podamos escalar
scaler = MinMaxScaler()

#Aplicamos normalizacion minmax sobre el dataset (hay que convertirlo en dataframe porque da un ndarray)
minmax_senecafe = pd.DataFrame(
    scaler.fit_transform(datos_senecafe.select_dtypes(include=[np.number])),
    columns=datos_senecafe.select_dtypes(include=[np.number]).columns
)

print("Datos normalizados (primeras filas):")
display(minmax_senecafe.head())
# Out:
# Datos normalizados (primeras filas):
#        Area  Perimetro  LongitudEjeMayor  LongitudEjeMenor  Excentricidad  \
# 0  0.195173   0.363164          0.413280          0.253645       0.913669
# 1  0.093300   0.164694          0.158723          0.230818       0.336618
# 2  0.149219   0.274699          0.349213          0.197979       0.915580
# 3  0.112213   0.197761          0.212544          0.230041       0.595676
# 4  0.125721   0.191063          0.293995          0.185988       0.595676
#
#    AreaConvexa  DiametroEquivalente    Medida  Compacidad  FactorForma1  \
# 0     0.196028             0.347246  0.210581    0.091260      0.345682
# 1     0.092951             0.188656  0.680331    0.593290      0.376598
# 2     0.148958             0.279781  0.100282    0.093881      0.438785
# 3     0.112868             0.220791  0.597379    0.444883      0.381107
# 4     0.126532             0.242877  0.204208    0.171909      0.460811
#
#    FactorForma2  FactorForma3  FactorForma4
# ...

# %% [markdown]
# Efectivamente, ahora los datos se encuentran en el rango [0,1], lo cual permite que no se generen sesgos (no se le dé más peso a una variable que realmente no lo tiene), por lo que no se afecta el cálculo de distancias y aumenta la calidad de los datos a procesar.

# %% [markdown]
# ## 6. Selección de variables

# %% [markdown]
# ### Mapa de correlación
#
# Hemos decidido ver el mapa de correlación de las variables para evitar que dos variables aporten prácticamenta la misma información al modelo al estar altamente correlacionadas. Si las mantenemos, podría inflarse la importancia de ciertos factores y cambiar el proceso de agrupamiento. Nuevamente, algoritmos como k-means o DBSCAN, podrían verse afectados de lo contrario. Si dos variables están altamente correlacionadas (correlación mayor a 0.9), aportan casi la misma información, así que pueden sesgar el agrupamiento al duplicar su peso.
#
# Por ello, hemos decidido eliminar las variables con correlación alta y solo conservar una de ellas, así mantenemos la información esencial para que los modelos logren tener mayor eficiencia.

# %%
#Calcular la matriz de correlación 
corr = minmax_senecafe.corr()

plt.figure(figsize=(12,8))

#Veamosla con mapa de calor para entender mejor
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm", center=0, linewidths=0.5)

plt.title("Mapa de correlación entre variables", fontsize=14)
plt.show()

# %%
#Ahora, eliminemos las variables más correlacionadas

#Matriz de correlación absoluta
correlacion = minmax_senecafe.corr().abs()

#Revisamos solo la parte superior de la matriz (para no duplicar)
parte_superior_matriz = correlacion.where(np.triu(np.ones(correlacion.shape), k=1).astype(bool))

# Variables a eliminar (umbral de 0.90)
columnas_a_eliminar = [columna for columna in parte_superior_matriz.columns if any(parte_superior_matriz[columna] > 0.90)]

# Dataset reducido
senecafe_reducido= minmax_senecafe.drop(columns=columnas_a_eliminar).copy()

print("Columnas eliminadas por correlación:", columnas_a_eliminar)
print("Dimensiones del dataset reducido:", senecafe_reducido.shape)
# Out:
# Columnas eliminadas por correlación: ['Perimetro', 'LongitudEjeMayor', 'LongitudEjeMenor', 'AreaConvexa', 'DiametroEquivalente', 'Compacidad', 'FactorForma1', 'FactorForma3']
# Dimensiones del dataset reducido: (7563, 5)

# %%
senecafe_reducido.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7563 entries, 0 to 7562
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Area           7563 non-null   float64
#  1   Excentricidad  7563 non-null   float64
#  2   Medida         7563 non-null   float64
#  3   FactorForma2   7563 non-null   float64
#  4   FactorForma4   7563 non-null   float64
# dtypes: float64(5)
# memory usage: 295.6 KB

# %% [markdown]
# ## 7. Modelamiento

# %% [markdown]
# ### 7.1. Implementación de K-means (Ana María Hernández)
#
# **Descripción del algoritmo**
#
# Primero, hay que entender que K-means divide a los datos en k grupos, buscando que los elementos dentro de un mismo grupo sean lo más parecidos posibles entre sí, y lo más diferentes posible respecto a los de otros grupos. Para lograrlo, el algoritmo define un centroide para cada cluster (o grupo) y asigna cada observación al centroide más cercano según la distancia (IBM, 2024).
#
# *Pasos de k-means*
# 1. Primero, se seleccionan los centroides iniciales de los *k* grupos.
# 2. Después, cada punto del conjunto de datos (conformado por las variables que hemos elegido) calcula su distancia a cada centroide y se asigna al grupo cuyo centroide esté más cercano.
# 3. Luego, se recalculan los centroides tomando el promedio de todos los puntos que quedaron en cada grupo.
# 4. Itera y acaba cuando los centroides dejan de cambiar o cuando alcanza el número máximo de iteraciones.
#
# **Decisiones de implementación**
#
# Recapitulemos las decisiones de implementación hechas hasta el momento para implementar k-means:
#
# 1. **Eliminación de outliers con IQR**: Se aplicó el método del rango intercuartílico (IQR), que identifica como outliers a los valores que se encuentran demasiado lejos del rango central de los datos. Esto se hace porque esos valores pueden llegar a distorsionas las distancias dentro de k-means, pues el cálculo y re-cálculo de los centroides puede ser poco representativo al unir uno de los outliers al grupo, lo cual afecta la calidad de la agrupación.
#
# 2. **Normalización de variables**: Se utilizó MinMaxScaler, que transforma cada variable al rango [0,1] (normaliza). Esta decisión se tomó porque el dataset incluía variables en escalas muy diferentes y podía inflar artificialmente algunos factores, lo cual alteraba en el cálculo de distancias.
#
# 3. **Reducción de variables por correlación**: Se eliminaron aquellas con correlación superior a 0.90, con el fin de evitar redundancia y mejorar la eficiencia, pues podían dar la misma información, y por ende, inflar el peso de dicha información en el cálculo de distancias, lo cual no es fiel a la realidad. Con esto, el dataset pasó a tener 5 variables, manteniendo la información esencial (sin repetición innecesaria).
#
# 4. **Método del codo**: Se usa para la elección de *k* (número de grupos). Graficaremos *k* (número de clusters) vs inercia.
#
# - La inercia nos indica qué tan compactos o “apretados” están los grupos formados; entre más baja sea la inercia, los puntos estarán más cercanos a su centroide. Al aumentar el número de clusters, la inercia tiende a disminuir, porque los grupos se vuelven más ajustados a los datos. Sin embargo, el objetivo del método del codo es identificar el punto en el que la reducción de la inercia deja de ser significativa (a ese punto le llamamos el codo). A partir de ese valor de k, agregar más clusters no mejora significativamente qué tan compactos son los grupos y se convierte en un “gasto innecesario", pues solo agrega complejidad al modelo (Rodríguez, 2023a).
#
# **Hiperparámetros**
#
# Para la implementación en Python usé la clase KMeans de la librería Scikit-learn, que permite configurar parámetros como init, n_init, max_iter y random_state (Scikit-learn, 2024).
#
# Entendamos por qué se usarán estos hiperparámetros:
#
# - **init**: `"k-means++"`, ayuda a buscar e inicializar con centroides dispersos, pues elige un primer centroide al azar, luego para los centroides que sigan usa puntos que estén más alejados de los centroides ya elegidos, y así los centroides iniciales estarán repartidos en distintas zonas. Esto hace que usualmente se necesiten menos iteraciones en el modelo, y por ende mejora la eficiencia.
#
# - **max_iter**: `300`, da el máximo de iteraciones máximas para llegar a los k grupos, así se asegura que el modelo tenga tiempo suficiente para acabar sus procesos sin alargar el cálculo e iterar sin necesidad. Sirve para que no se quede calculando indefinidamente.
#
# - **n_init**: `10`, controla cuántos intentos hace K-means para buscar la mejor inicialización. Básicamente, el algoritmo se ejecuta varias veces completas (cada vez con distintos centroides iniciales), y al final se queda con la mejor solución (la que tenga menor inercia).
#
# - **random_state**: `42`, segura que los n_init intentos sean los mismos cada vez que se ejecuta el código, porque como K-means elige centroides al azar al inicio, random_state hace que siempre se usen los mismos centroides, así entre ejecuciones no cambian los resultados.
#
# - **n_clusters**: define en cuántos grupos vamos a dividir los datos.

# %%
from sklearn.cluster import KMeans

sse = []
k_range = range(2, 10)

#Hay que iterar en diferentes cantidades de grupos en los que vamos a dividir los datos
for k in k_range:
    km = KMeans(n_clusters=k, init="k-means++", max_iter=300, n_init=10, random_state=42) #Hay que graficar los diferentes clusters 
    km.fit(senecafe_reducido)
    sse.append(km.inertia_) #Grafico de clusters vs inercia
plt.figure()
plt.plot(k_range, sse, marker='o')
plt.xlabel('Número de clusters')
plt.ylabel('Inercia (SSE)')
plt.title('Curva de Elbow para KMeans')
plt.tight_layout()
plt.show()
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] El sistema no puede encontrar el archivo especificado
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\subprocess.py", line 1026, in __init__
# ...

# %% [markdown]
# - El codo más claro parece estar en 5 clusters, porque allí cambia la pendiente. Podemos ver que antes de 5 la caída es mucho más notable y brusca, después de 5 se aplana un poco más. Probaremos con k = 5.

# %%
#Creo el modelo
kmeans =KMeans(n_clusters=5, init="k-means++", max_iter=300, n_init=10, random_state=42)
#Obtengo las etiquetas de cluster (números de grupo que se le dan a cada una de las observaciones o registros)
clusters = kmeans.fit_predict(senecafe_reducido)

# %% [markdown]
# Ahora visualizaremos las siluetas para cada cluster. El coeficiente de silueta mide qué tan bien quedó asignado un punto a su cluster comparado con otros clusters.
#
# - Si el coeficiente de silueta se acerca a 1, es porque el punto está bien agrupado. Si se acerca a 0, es porque el punto está en el límite con otro cluster. Si es un valor negativo, es muy probable que el punto haya quedado mal asignado.

# %%
from sklearn.metrics import silhouette_score, silhouette_samples
cluster_labels = kmeans.labels_
silhouette_vals = silhouette_samples(senecafe_reducido, cluster_labels)
silhouette_avg = silhouette_score(senecafe_reducido, cluster_labels)
plt.figure(figsize=(8, 5))
y_lower = 10

#Debemos iterar para los 5 clusters
for i in range(5):
    ith = silhouette_vals[cluster_labels == i]
    ith.sort()
    size_i = ith.shape[0]
    y_upper = y_lower + size_i
    plt.fill_betweenx(np.arange(y_lower, y_upper), 0, ith)
    plt.text(-0.05, y_lower + 0.5 * size_i, str(i))
    y_lower = y_upper + 10

#Queremos que se muestre el coeficiente explicitamente 
plt.axvline(x=silhouette_avg, color="red", linestyle="--")
plt.text(silhouette_avg+0.01, y_lower/2, f"Promedio: {silhouette_avg:.3f}", 
         color="red", fontsize=12)
plt.xlabel("Valor de la silueta")
plt.ylabel("Cluster")
plt.title("Visualización de siluetas para cada cluster")
plt.tight_layout()
plt.show()

# %% [markdown]
# La línea roja nos dice el coeficiente de silueta promedio de todos los puntos, que en este caso, es 0.25. No es mayor a 0.5, que sería lo aceptable.
#
# Podemos ver que
# - El cluster azul es el más grande y tiene siluetas relativamente buenas (algunas cercanas a 0.5).
# - Los clusters naranja y verde son medianos, pero con siluetas que llegan a valores bajos (0 o incluso negativos). Esto nos dice que algunos puntos pudieron asignarse mal o que están muy cerca de otros clusters.
# - El cluster rojo tiene buen comportamiento, con la mayoría de puntos en valores aceptables (>0.25).
#
# Como el coeficiente promedio es bajo, vemos que los clusters no están perfectamente separados, aunque si existe cierta estructura.

# %% [markdown]
# **Nueva decisión de implementación**
#
# 5. **Probar con diferentes k y comparar sus métricas**: En vista de que el coeficiente de silueta promedio fue bajo (0.27 aproximadamente), se decidió no quedarnos solo con un valor fijo de k.
#
# - En su lugar, se probarán diferentes cantidades de clusters y se compararán tanto el coeficiente de silueta como otras dos métricas denominadas índice de Calinski-Harabasz e índice de Davies-Bouldin. La primera se ocupa de medir la razón entre la dispersión entre los clústeres y la dispersión dentro de los clústeres, por lo que entre más alto, es mejor, pues significaría que la varianza entre ellos es mayor que la varianza dentro de ellos (Rodríguez, 2023b). Por otra parte, Davies-Bouldin se usa para ver qué tan similares son los clústeres entre sí, por lo que entre más bajo, es mejor, ya que queremos que los grupos estén más separados (Rodríguez, 2023c).

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
import pandas as pd
import numpy as np

def evaluar_kmeans(X, posibles_k=range(2, 13)):
    #Aqui se van a añadir las metricas de k-means para cada k
    resultados = []
    for k in posibles_k:

        km = KMeans(
            n_clusters=k,
            init="k-means++",
            n_init=10,          
            max_iter=300,
            random_state=42
        )

        #Obtengo las etiquetas de cluster (números de grupo que se le dan a cada una de las observaciones o registros)
        labels = km.fit_predict(X)

        sil = silhouette_score(X, labels)
        cal = calinski_harabasz_score(X, labels)
        dav = davies_bouldin_score(X, labels)

        resultados.append((k, sil, cal, dav))
    
    #Dataframe para que podamos mostrar los resultados
    df = pd.DataFrame(resultados, columns=["k", "silhouette", "calinski", "davies"])
    return df

resumen = evaluar_kmeans(senecafe_reducido)
resumen
# Out:
#      k  silhouette     calinski    davies
# 0    2    0.320209  4467.466769  1.230649
# 1    3    0.246284  3612.091487  1.350502
# 2    4    0.255844  3351.122025  1.297685
# 3    5    0.249893  3141.153998  1.303223
# 4    6    0.249591  3033.771908  1.262578
# 5    7    0.253805  2867.309464  1.170660
# 6    8    0.240701  2771.349605  1.188245
# 7    9    0.236498  2645.659426  1.191520
# 8   10    0.235448  2528.534351  1.183955
# 9   11    0.227501  2441.427666  1.203548
# 10  12    0.223164  2335.094048  1.228343

# %% [markdown]
# **Número de clusters**
#
# Como podemos ver, el mejor k (número de clusters) es 2.
#
# - Esto es porque tiene el máximo coeficiente de silueta (0.32), lo cual indica que con dos clusters la separación es más clara. Igualmente, tiene el índice de  Calinski–Harabasz más alto (4467), y a partir de k=3 en adelante, este disminuye, lo que nos dice que dividir mucho los datos hace que la calidad de los clusters sea menor. Además, k = 2 tiene un índice Davies–Bouldin bajo, que aunque no es el menor, es similar a los menores (1.23, cuando el menor es 1.17), no hay diferencias grandes.
#
# - Realicemos el modelo final con k =2:

# %%
#Modelo final con k=2

kmeans_final = KMeans(n_clusters=2, init="k-means++", n_init=10, max_iter=300, random_state=42)

#Obtengo las etiquetas de cluster (números de grupo que se le dan a cada una de las observaciones o registros)
labels_final = kmeans_final.fit_predict(senecafe_reducido)

# %%
from sklearn.metrics import silhouette_score, silhouette_samples
cluster_labels = kmeans_final.labels_
silhouette_vals = silhouette_samples(senecafe_reducido, cluster_labels)
silhouette_avg = silhouette_score(senecafe_reducido, cluster_labels)
plt.figure(figsize=(8, 5))
y_lower = 10

#Iteramos para los 2 clusters
for i in range(2):
    ith = silhouette_vals[cluster_labels == i]
    ith.sort()
    size_i = ith.shape[0]
    y_upper = y_lower + size_i
    plt.fill_betweenx(np.arange(y_lower, y_upper), 0, ith)
    plt.text(-0.05, y_lower + 0.5 * size_i, str(i))
    y_lower = y_upper + 10

#Otra vez quiero mostrar el coeficiente explicito
plt.axvline(x=silhouette_avg, color="red", linestyle="--")
plt.text(silhouette_avg+0.01, y_lower/2, f"Promedio: {silhouette_avg:.3f}", 
         color="red", fontsize=12)

plt.xlabel("Valor de la silueta")
plt.ylabel("Cluster")
plt.title("Visualización de siluetas para cada cluster")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Resultados obtenidos:**
#
# - El coeficiente promedio es 0.32, lo cual hace mejoría ante el coeficiente de k=5, que era 0.25. Aunque sigue sin superar a 0.5, lo que podemos concluir a partir de esto es que sí existe cierta estructura al momento de agrupar los granos de café, pero no es muy fuerte.
#
# - El cluster azul es grande, y la mayoría de puntos tiene siluetas positivas (0.2–0.4). Hay pocos puntos cerca de cero o negativos, lo cual significa que la mayoría está bien asignada.
#
# - El cluster verde también es grande, y los puntos tienen siluetas positivas. Algunos incluso alcanzan siluetas de 0.4 y 0.5, que es bastante bueno.
#
# - Hay mejoría para k = 2, que nos indica que los clusters son estables y bien separados en general para dos grupos, aunque estos no estén perfectamente compactos. Es decir, el mejor resultado se obtiene cuando concluimos que hay dos tipos de granos.

# %%
silhouette_avg_KN = silhouette_score(senecafe_reducido, labels_final)
calinski_KN = calinski_harabasz_score(senecafe_reducido, labels_final)
davies_KN = davies_bouldin_score(senecafe_reducido, labels_final)

print("Silhouette Score:", silhouette_avg_KN)
print("Calinski-Harabasz Score:", calinski_KN)
print("Davies-Bouldin Score:", davies_KN)
# Out:
# Silhouette Score: 0.3202094762611336
# Calinski-Harabasz Score: 4467.46676861266
# Davies-Bouldin Score: 1.2306488002345262

# %% [markdown]
# **Análisis de Métricas de Agrupación**
#
# **Silhouette Score:**
# Esta métrica mide qué tan bien definidos están los clústeres. Compara la distancia de un punto con los de su propio clúster frente a la distancia con los puntos del clúster más cercano. El valor va de -1 a 1 y se considera bueno entre más cercano esté a 1. Tuvimos un valor de 0.320, lo cual es un resultado modesto. Un valor por debajo de 0.5 sugiere que los clústeres podrían tener una estructura débil o que existe un solapamiento considerable entre ellos, indicando que la separación no es muy clara.
#
# **Calinski-Harabasz Score:**
# Esta mide la relación entre la dispersión entre los clústeres y la dispersión dentro de cada clúster. El valor va de 0 hacia arriba y más alto es mejor. Se usa principalmente para comparar diferentes resultados de clustering sobre los mismos datos. Este modelo tuvo un valor de 4467.467. Por sí solo, este número no es concluyente, pero al compararlo con otros modelos, un valor más bajo generalmente indica que los clústeres son menos densos o están menos separados.
#
# **Davies-Bouldin Score:**
# Esta métrica mide la "similitud" promedio de cada clúster con su vecino más cercano. Su valor va de 0 hacia arriba, y a diferencia de las otras métricas, más bajo es mejor. Tenemos un valor de 1.231. Al ser un puntaje superior a 1, indica que existe una superposición significativa entre los clústeres. Sugiere que los grupos no son claramente distintos y comparten características, lo que debilita la calidad de la agrupación.

# %% [markdown]
# Ahora veamos la cantidad de registros de granos de café por cada cluster:

# %%
senecafe_reducido["Cluster"] = kmeans_final.labels_
print(senecafe_reducido['Cluster'].value_counts())
# Out:
# Cluster
# 0    4403
# 1    3160
# Name: count, dtype: int64

# %% [markdown]
# - Los dos grupos son grandes y están relativamente balanceados: (58% de los registros en el cluster 0 y 42% de los registros en el cluster 1), no hay un grupo dominante. Esto nos sugiere que los datos presentan dos tipos principales de morfología o compartamiento, ambas con peso suficiente como para ser relevantes en el análisis.

# %%
sns.pairplot(senecafe_reducido, hue="Cluster", palette="tab10")
plt.suptitle("Comportamiento en parejas de atributos por cluster")
plt.tight_layout()
plt.show()

# %%
senecafe_reducido=senecafe_reducido.drop(columns=["Cluster"]) #Quitamos la columna label para los próximos algoritmos

# %% [markdown]
# Gracias a los gráficos de la diagonal, podemos interpretar lo siguiente:
# - En el cluster azul (0) están los granos de café que tienen áreas más bajas, mientras que en el cluster naranja (1) hay una ligera tendencia a áreas más grandes de café.
# - El cluster azul comprende granos de café con medidas más grandes, mientras que el naranja tiene granos con valores más bajos de medidas.
# - En cuanto a FactorForma2, se distinguen dos picos bien diferenciados. El cluster azul tiende a valores más altos, el naranja a valores más bajos.
# - En FactorForma4, también hay gran diferencia. El cluster azul tiene granos con valores más altos, el naranja con valores más bajos.
# - En cuanto a Excentricidad, ambos clusters se mezclan bastante, aunque el azul parece cubrir un rango un poco más amplio.

# %% [markdown]
# Gracias a los gráficos fuera de la diagonal, podemos interpretar lo siguiente
#
# - Medida vs FactorForma2 y Medida vs FactorForma: el cluster azul tiende a concentrarse en valores altos de Medida junto con altos valores en FactorForma2 y FactorForma4, mientras que el naranja se ubica en valores más bajos en esas combinaciones. Esto describe la relación entre esas variables.
#
# - FactorForma2 vs FactorForma4: hay una división clara, el cluster azul contiene a los granos de café con tendencia hacia valores altos en ambos factores, y naranja hacia valores más bajos.
#
# - FactorForma2 vs Excentricidad: se ve que el cluster azul se extiende hacia valores altos de FactorForma2, mientras que el naranja se concentra en valores más bajos.
#
# - Excentricidad vs Área: se observa que el cluster naranja está un poco más cargado hacia áreas mayores, mientras que el azul domina en áreas más bajas.

# %% [markdown]
# **En conclusión:**
# - La implementación de K-means permitió identificar dos grupos principales de granos de café con diferencias morfológicas claras, lo cual se puede ver en los diagrama de parejas que obtuvimos al final.
#
# - Aunque el método del codo sugería inicialmente k=5, la comparación de métricas internas (Silhouette, Calinski-Harabasz y Davies-Bouldin) mostró que k=2 ofrecía una mejor separación y estabilidad de los clusters.
#
# - El coeficiente de silueta promedio (0.32) indica que, aunque los grupos no son perfectamente compactos, sí existe una estructura relevante en los datos que tenemos, la cual permite diferenciarlos.
#
# - Esto refleja la importancia de complementar técnicas visuales como el codo con métricas objetivas que permitan validar la calidad.
#
# - Los dos clusters obtenidos son suficientemente grandes y balanceados, y al ser pocos grupos, puede resultar práctico para la organización al momento de entenderlos.
#
# - En conjunto, las métricas no son tan favorables, pues aunque se han identificado dos tendencias o arquetipos de granos de café, en la realidad los datos forman más bien un continuo. No son dos islas de datos separadas, sino dos "regiones" densas con una zona de transición entre ellas.

# %% [markdown]
# **Fuentes**
#
# - IBM. (2024, junio 26). *¿Qué es la agrupación en clústeres k-means?* IBM Think. https://www.ibm.com/mx-es/think/topics/k-means-clustering
#
# - Rodríguez, D. (2023, junio 30). *El índice de Davies-Bouldin para estimar los clústeres en K-means e implementación en Python.* Analytics Lane. https://www.analyticslane.com/2023/06/30/el-indice-de-davies-bouldinen-para-estimar-los-clusteres-en-k-means-e-implementacion-en-python/
#
# - Rodríguez, D. (2023, junio 9). *Método del codo (Elbow method) para seleccionar el número óptimo de clústeres en K-means.* Analytics Lane. https://analyticslane.com/2023/06/09/metodo-del-codo-elbow-method-para-seleccionar-el-numero-optimo-de-clusteres-en-k-means/
#
# - Rodríguez, D. (2023, junio 16). *Identificar el número de clústeres con Calinski-Harabasz en K-means e implementación en Python.* Analytics Lane. https://analyticslane.com/2023/06/16/identificar-el-numero-de-clusteres-con-calinski-harabasz-en-k-means-e-implementacion-en-python/
#
#
# - Scikit-learn. (2024). *sklearn.cluster.KMeans.* En Scikit-learn 1.7.0 documentation. https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html

# %% [markdown]
# ### 7.2. Implementación de Gaussian Mixture Models-GMM (Juan Sebastián Ardila López)
#
# Este es un algoritmo probabilístico, GMM asume que los puntos de datos se generan a partir de una mezcla de varias distribuciones gaussianas (con forma de campana) con parámetros desconocidos. El algoritmo encuentra los parámetros de estas distribuciones y calcula la probabilidad de que cada punto de datos pertenezca a cada uno de los clústeres. Este tipo de clustering es lo que se conoce como soft clustering.
#
# **Pasos de GMM**
# 1. Primero, el algoritmo hace una suposición inicial sobre los parámetros de cada cluster, en estos, asume la media $\mu$, covarianza $\Sigma$ t los pesos $\Pi$ de cada cluster (la proporción o importancia de este cluster en la mezcla final).
# 2. El algoritmo entra en una etapa conocida como "Expectation". En esta etapa el algoritmo toma como base los pesos que conoce y calcula la probabilidad de que un dato que acaba de ver pertenezca a los clusters que tiene identificados anteriormente (soft assignment).
# 3. Posterior a este paso, el algoritmo entra an una etapa conocida como "Maximization", y es que al haber visto un dato nuevo, el algoritmo utiliza las probabilidades que calculó anteriormente para actualizar los parámetros de cada cluster (media, covarianza y peso). Lo anterior se hace con el objetivo de maximizar la verosimilitud de los datos dadas las asignaciones de probabilidad.
# 4. Se repiten los pasos 2 y 3 hasta que los parámetros de las gaussianas dejan de cambiar significativamente entre una y otra iteración, en este punto se dice que el algoritmo alcanzó convergencia.
#
# **Decisiones de implementación**
#
# Recapitulemos las decisiones de implementación hechas hasta el momento para implementar GMM:
#
# 1. **Normalización de variables**: Se utilizó MinMaxScaler, que transforma cada variable al rango [0,1] (normaliza). Esta decisión se tomó porque el dataset incluía variables en escalas muy diferentes y podía inflar artificialmente algunos factores.
#
# 2. **Reducción de variables por correlación**: Se eliminaron aquellas con correlación superior a 0.90, con el fin de evitar redundancia y mejorar la eficiencia. Con esto, el dataset pasó de 15 a 7 variables, pero manteniendo la información esencial (no hubo repetición innecesaria).
#
# **Hiperparámetros**
#
# Entendamos por qué se usaron estos hiperparámetros:
# <!--  -->
# - **n_components**: `A iterar`. Define el número de clústeres (o distribuciones gaussianas) que el algoritmo debe encontrar. Se suele elegir de 2 a 10 y se escoge utilizando métricas como Coeficiente de Silueta, Akaike Information Criterion, o Bayesian Information Criterion.
#
# - **covariance_type**: `full`.Define la forma y orientación de los clústeres, controlando las propiedades de sus matrices de covarianza.. Define la forma y orientación de los clústeres, controlando las propiedades de sus matrices de covarianza.
#     - `full`. Cada clúster tiene su propia matriz de covarianza, lo que permite que los clústeres tengan forma de elipse con cualquier orientación y tamaño.
#     - `tied`. Todos los clústeres comparten la misma matriz de covarianza. Esto significa que todos los clústeres tendrán la misma forma y orientación elíptica, aunque pueden tener centros diferentes.
#     - `spherical` Cada clúster tiene una única varianza. Esto restringe la forma de los clústeres a ser perfectamente esféricos, de forma similar a K-Means, aunque los tamaños (radios) pueden variar.
#
# - **init_params**: `kmeans`. Utiliza los resultados de K-Means para establecer las posiciones iniciales de los centros de los clústeres. Suele ser muy eficaz y estable.
#
# - **n_init**: `10`. Hace que se ejecute E-M varias veces con diferentes centroides al inicial y poder elegir la mejor solución entre las ejecuciones.
#
# - **tol**: `1e-3`. El umbral para decidir que el modelo ha convergido. Si la mejora en la verosimilitud entre dos iteraciones es menor que este valor, el algoritmo se detiene.
#
# - **random_state**: `42`. Como E-M elige centroides al azar al inicio, random_state hace que siempre se usen los mismos centroides, así entre ejecuciones no cambian los resultados. Se puede poner cualquier número porque no afecta el algoritmo en sí, aunque por convención se usa el 42.
#
# Fuentes:
#
# - "Mastering Gaussian Mixture Models with Scikit-Learn in Python" por Ryan & Matt Data Science, publicado el 19 de diciembre de 2024, en YouTube, URL: http://www.youtube.com/watch?v=oHYhMG0wZOw [00:00].
# - "GaussianMixture" por scikit-learn developers, accedido el 22 de septiembre de 2025, en scikit-learn, URL: https://scikit-learn.org/stable/modules/generated/sklearn.mixture.GaussianMixture.html.

# %%
senecafe_reducido
# Out:
#           Area  Excentricidad    Medida  FactorForma2  FactorForma4
# 0     0.195173       0.913669  0.210581      0.119457      0.138856
# 1     0.093300       0.336618  0.680331      0.562992      0.789361
# 2     0.149219       0.915580  0.100282      0.155191      0.544239
# 3     0.112213       0.595676  0.597379      0.378319      0.499465
# 4     0.125721       0.595676  0.204208      0.219868      0.657493
# ...        ...            ...       ...           ...           ...
# 7558  0.059048       0.345857  0.599635      0.644393      0.890021
# 7559  0.310174       0.871049  0.770503      0.083034      0.453769
# 7560  0.095931       0.629555  0.336771      0.399244      0.744065
# 7561  0.343430       0.823927  0.715608      0.091056      0.425054
# 7562  0.088868       0.034687  0.584171      0.711089      0.910465
#
# [7563 rows x 5 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.mixture import GaussianMixture
from sklearn.datasets import make_blobs

def evaluar_gmm(X, posibles_n=range(2, 13)):
    resultados = []

    for n in posibles_n:
        gmm = GaussianMixture(n_components=n, covariance_type='full', init_params='kmeans', n_init=10, tol=1e-4, random_state=42)
        labels = gmm.fit_predict(X)

        sil = silhouette_score(X, labels)
        cal = calinski_harabasz_score(X, labels)
        dav = davies_bouldin_score(X, labels)

        resultados.append((n, sil, cal, dav))

    return pd.DataFrame(resultados, columns=["n", "silhouette", "calinski", "davies"])

resumen_gmm = evaluar_gmm(senecafe_reducido)
print("Análisis cuantitativo")
display(resumen_gmm)
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\mixture\_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\mixture\_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# Análisis cuantitativo
#      n  silhouette     calinski    davies
# 0    2    0.201633  2111.854524  1.767221
# 1    3    0.142136  1558.573202  2.903604
# 2    4    0.093531  1416.490609  4.678632
# 3    5    0.076045  1326.299755  4.084991
# 4    6    0.034637   994.952433  3.975712
# 5    7    0.070594  1030.047641  3.847877
# 6    8    0.032473   977.597847  3.790724
# 7    9    0.050892   846.426951  4.349189
# ...

# %%
plt.plot(resumen_gmm['n'], resumen_gmm['silhouette'], marker='o', label='Silhouette Score')
plt.title('Evaluación de GMM con diferentes números de componentes')
plt.xlabel('Número de componentes (n)')
plt.ylabel('Puntaje')
plt.xticks(resumen_gmm['n'])
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Se puede observar que el mejor coeficiente de silueta ocurre para n=2, es decir, dos tipos de granos clasificados. Construimos entonces nuestro modelo sobre este valor

# %%
gmm = GaussianMixture(n_components=2, covariance_type='full', init_params='kmeans', n_init=10, tol=1e-4, random_state=42)
labels = gmm.fit_predict(senecafe_reducido)

#Veamos como es cada cluster
print("Tamaño de cada cluster:")
print(pd.Series(labels, name="Cluster").value_counts())
# Out:
# Tamaño de cada cluster:
# Cluster
# 1    4290
# 0    3273
# Name: count, dtype: int64

# %%
df_fgmm=senecafe_reducido.copy()
df_fgmm["Cluster_GMM"] = labels

# %%
silhouette_vals = silhouette_samples(senecafe_reducido,labels)
silhouette_avg = silhouette_score(senecafe_reducido, labels)
plt.figure(figsize=(8, 5))
y_lower = 10

#Iteramos para los 2 clusters
for i in range(2):
    ith = silhouette_vals[labels == i]
    ith.sort()
    size_i = ith.shape[0]
    y_upper = y_lower + size_i
    plt.fill_betweenx(np.arange(y_lower, y_upper), 0, ith)
    plt.text(-0.05, y_lower + 0.5 * size_i, str(i))
    y_lower = y_upper + 10

#Otra vez quiero mostrar el coeficiente explicito
plt.axvline(x=silhouette_avg, color="red", linestyle="--")
plt.text(silhouette_avg+0.01, y_lower/2, f"Promedio: {silhouette_avg:.3f}", 
         color="red", fontsize=12)

plt.xlabel("Valor de la silueta")
plt.ylabel("Cluster")
plt.title("Visualización de siluetas para cada cluster")
plt.tight_layout()
plt.show()

# %%
sns.pairplot(df_fgmm, hue="Cluster_GMM", palette="tab10")
plt.suptitle("Comportamiento en parejas de atributos por cluster (GMM)")
plt.tight_layout()
plt.show()

# %% [markdown]
# Podemos concluir que las tendencias generales

# %%
# Metricas del modelo
silhouette_avg_GMM = silhouette_score(senecafe_reducido, labels)
calinski_GMM = calinski_harabasz_score(senecafe_reducido, labels)
davies_GMM = davies_bouldin_score(senecafe_reducido, labels)

print("Silhouette Score:", silhouette_avg_GMM)
print("Calinski-Harabasz Score:", calinski_GMM)
print("Davies-Bouldin Score:", davies_GMM)
# Out:
# Silhouette Score: 0.20163280726740693
# Calinski-Harabasz Score: 2111.854524420442
# Davies-Bouldin Score: 1.7672211777527298

# %% [markdown]
# **Análisis de Métricas de Agrupación**
#
# - **Silhouette Score:**
# Esta métrica mide qué tan bien definidos están los clústeres. Compara la distancia de un punto con los de su propio clúster frente a la distancia con los puntos del clúster más cercano. El valor va de -1 a 1 y se considera bueno entre mas cercano este a 1. El modelo de GMM obtuvo un valor de 0.651, lo cual es un buen resultado. Un valor por encima de 0.5 indica que los dos clústeres que se encontraron tienen una estructura clara y están razonablemente bien separados entre sí.
#
# - **Calinski-Harabasz Score:**
# Esta mide la relación entre la dispersión entre los clústeres y la dispersión dentro de cada clúster. El valor va de 0 hacia arriba. Más alto es mejor. Se usa principalmente para comparar diferentes resultados de clustering sobre los mismos datos. (Como haremos mas adelante)
# Este modelo tuvo un valor de 22301.81 que por sí solo, es una señal positiva, ya que sugiere que los clústeres son compactos y están lejos unos de otros
#
# - **Davies-Bouldin Score:**
# Esta métrica mide la "similitud" promedio de cada clúster con su vecino más cercano, donde la similitud se define por la relación entre el tamaño de los clústeres y la distancia entre ellos. Su valor va de 0 hacia arriba, y a diferencia de las otras métricas, más bajo es mejor. Un puntaje de 0 sería perfecto. Tenemos un valor de 0.5508, lo que indica que la superposición o ambigüedad entre tus dos clústeres es mínima. Cada clúster es claramente distinto de su vecino.

# %% [markdown]
# Se puede ver en los histogramas que el algortimo hace que las distribuciones de los parámetros sean parcialmente normales, lo cual sigue la filosofía del algoritmo. Sin embargo, el algoritmo siguiendo este procedimiento no es capaz de alcanzar resultados como los de KNN.

# %% [markdown]
# ### 7.3. Implementación de DBSCAN (William Bayona Vergara)
#
# DBSCAN (Density-Based Spatial Clustering of Applications with Noise) es un algoritmo de agrupamiento que funciona encontrando áreas de alta densidad en los datos y expandiendo los clústeres a partir de ellas. Es particularmente bueno para encontrar clústeres de formas arbitrarias y para identificar valores atípicos (ruido).
#
# A diferencia de algoritmos como K-Means, DBSCAN no requiere que se especifique el número de clústeres de antemano. En su lugar, opera bajo dos parámetros clave:
#
# - **Epsilon (eps):** La distancia máxima entre dos puntos para que se consideren vecinos.
#
# - **Puntos Mínimos (min_samples):** El número mínimo de puntos requeridos dentro del radio eps para formar una región densa (un clúster).
#
# El algoritmo clasifica los puntos como núcleo (puntos en el interior de un clúster), frontera (puntos en el borde de un clúster) o ruido (valores atípicos). Su principal fortaleza radica en su capacidad para identificar clústeres de formas arbitrarias y su robustez ante el ruido, lo que lo hace ideal para conjuntos de datos complejos donde los grupos no son necesariamente esféricos.
#
#
# **Pasos de DBSCAN**
#
# 1. Selección y Clasificación: El algoritmo comienza con un punto arbitrario no visitado. Evalúa si es un punto núcleo al contar cuántos vecinos tiene dentro de la distancia eps. Si el número de vecinos es igual o mayor a min_samples, se considera un punto núcleo; de lo contrario, se etiqueta temporalmente como ruido.
#
# 2. Creación y Expansión del Clúster:
#
#     - Si el punto es un núcleo, se crea un nuevo clúster y tanto él como todos sus vecinos se añaden a este.
#
#     - El algoritmo expande el clúster de forma recursiva: por cada vecino añadido que también sea un punto núcleo, sus propios vecinos se agregan al clúster. Este proceso continúa hasta que el clúster ya no puede crecer más.
#
# 3. Iteración: El algoritmo pasa a un nuevo punto no visitado del conjunto de datos y repite el proceso desde el paso 1.
#
# 4. Finalización: El proceso concluye cuando todos los puntos han sido visitados y asignados a un clúster o clasificados de forma definitiva como ruido.

# %% [markdown]
# **Determinación de Hiperparametros**

# %% [markdown]
# Para la determinación del parámetro **min_samples**, el enfoque ideal consistiría en consultar a un experto en el dominio, como un conocedor de agronomía o catación de café Este conocimiento de dominio nos permitiría definir el tamaño mínimo que debe tener un grupo de granos para ser considerado significativo y no una simple coincidencia. Sin embargo, en ausencia de esta validación experta y con el objetivo de mantener un rigor matemático, se optará por un punto de partida heurístico.
#
# Para ello, estableceremos el valor de min_samples siguiendo la recomendación estándar de 2 * D, donde D es el número de dimensiones o características del conjunto de datos. Esta regla práctica es ampliamente utilizada porque se ajusta a la complejidad de los datos, ayudando a mitigar los efectos de la "maldición de la dimensionalidad" y asegurando que nuestra definición de "clúster denso" sea robusta.

# %% [markdown]
# Para encontrar un buen valor para eps, podemos utilizar la técnica del "gráfico del codo", que nos ayuda a identificar la distancia en la que la pendiente de la curva de distancias de los vecinos más cercanos cambia de forma más pronunciada. El valor ideal de **eps** se encuentra en el punto de máxima curvatura del grafico. Es decir el punto donde la curva deja de subir bruscamente y comienza a aplanarse.

# %%
senecafe_reducido
# Out:
#           Area  Excentricidad    Medida  FactorForma2  FactorForma4
# 0     0.195173       0.913669  0.210581      0.119457      0.138856
# 1     0.093300       0.336618  0.680331      0.562992      0.789361
# 2     0.149219       0.915580  0.100282      0.155191      0.544239
# 3     0.112213       0.595676  0.597379      0.378319      0.499465
# 4     0.125721       0.595676  0.204208      0.219868      0.657493
# ...        ...            ...       ...           ...           ...
# 7558  0.059048       0.345857  0.599635      0.644393      0.890021
# 7559  0.310174       0.871049  0.770503      0.083034      0.453769
# 7560  0.095931       0.629555  0.336771      0.399244      0.744065
# 7561  0.343430       0.823927  0.715608      0.091056      0.425054
# 7562  0.088868       0.034687  0.584171      0.711089      0.910465
#
# [7563 rows x 5 columns]

# %%
from sklearn.neighbors import NearestNeighbors
import numpy as np
import matplotlib.pyplot as plt

# Calculamos la distancia de cada punto a sus 'k' vecinos más cercanos
min_samples = 2 * senecafe_reducido.shape[1]
neighbors = NearestNeighbors(n_neighbors=min_samples)
neighbors_fit = neighbors.fit(senecafe_reducido)
distances, indices = neighbors_fit.kneighbors(senecafe_reducido)

# Ordenamos las distancias de menor a mayor
sorted_distances = np.sort(distances[:, -1])

# Graficamos las distancias ordenadas
plt.figure(figsize=(12, 7))

# Eje X: Las distancias ordenadas
# Eje Y: El rango o la cuenta de puntos
plt.plot(sorted_distances, range(len(sorted_distances)))
plt.xticks(np.arange(0, 0.6, 0.02), rotation=45)
plt.title('Gráfico de Codo')
plt.xlabel(f'Distancia al {min_samples}-ésimo Vecino')
plt.ylabel('Cantidad de Puntos Acumulados')
plt.grid(True)
plt.show()

#Calcular epsilon optimo (punto de mayor curbatura)
from kneed import KneeLocator
kneedle = KneeLocator(
    range(len(sorted_distances)), 
    sorted_distances, 
    curve="convex", 
    direction="increasing"
)

# %% [markdown]
# A partir del análisis del diagrama podemos identificar un eps optimo de aproximadamente 0.12, que es el punto donde se evidencia mayor curvatura

# %% [markdown]
# A continuacion vamos a entrenar el modelo de DBSCAN y revisar nuestras metricas de evaluación

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.metrics import (
    silhouette_score,
    calinski_harabasz_score,
    davies_bouldin_score,
    silhouette_samples, # Faltaba este import en el código original
)

# --- PARÁMETROS DEL MODELO ---
# Se definen los parámetros para el algoritmo DBSCAN.
# Estos valores usualmente se obtienen de un análisis previo (como el método del codo).
min_samples = 2 * senecafe_reducido.shape[1]  # El doble del número de características
eps = 0.12

# --- ENTRENAMIENTO DEL MODELO ---
# Se inicializa y entrena el modelo DBSCAN con los datos y parámetros definidos.
dbscan = DBSCAN(eps=eps, min_samples=min_samples)
clusters = dbscan.fit_predict(senecafe_reducido) # Asegúrate de que 'senecafe_reducido' esté definido

# --- ANÁLISIS DE RESULTADOS ---
# Se crea una máscara para excluir los puntos de ruido (etiquetados como -1).
mask = clusters != -1

# Se cuenta el número de clústeres y puntos de ruido.
n_clusters = len(set(clusters[mask]))
n_noise = list(clusters).count(-1)

print(f"Número de clústeres encontrados: {n_clusters}")
print(f"Número de puntos de ruido: {n_noise} (de un total de {len(senecafe_reducido)} puntos)")
print("-" * 30) # Separador para mayor claridad

# --- MÉTRICAS DE EVALUACIÓN ---
# Las métricas de evaluación solo se pueden calcular si hay al menos 2 clústeres.
if n_clusters >= 2:
    # Se calculan las métricas usando solo los datos que pertenecen a un clúster.
    silhouette_DBSCAN = silhouette_score(senecafe_reducido[mask], clusters[mask])
    calinski_DBSCAN = calinski_harabasz_score(senecafe_reducido[mask], clusters[mask])
    davies_DBSCAN = davies_bouldin_score(senecafe_reducido[mask], clusters[mask])
    
    print(f"Silhouette Score: {silhouette_DBSCAN:.3f}")
    print(f"Calinski-Harabasz Score: {calinski_DBSCAN:.3f}")
    print(f"Davies-Bouldin Score: {davies_DBSCAN:.3f}")
    
    # --- VISUALIZACIÓN: GRÁFICO DE SILUETA ---
    labels_clustered = clusters[mask]
    silhouette_vals = silhouette_samples(senecafe_reducido[mask], labels_clustered)
    
    plt.figure(figsize=(10, 6))
    y_lower = 10
    
    for i in range(n_clusters):
        # Se obtienen los valores de silueta para cada clúster.
        ith_cluster_silhouette_values = silhouette_vals[labels_clustered == i]
        ith_cluster_silhouette_values.sort()
        
        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i
        
        # Se asigna un color a cada clúster.
        color = plt.cm.viridis(float(i) / max(n_clusters, 1))
        plt.fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            ith_cluster_silhouette_values,
            facecolor=color,
            edgecolor=color,
            alpha=0.7,
        )
        
        # Se etiqueta cada clúster en el gráfico.
        plt.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
        y_lower = y_upper + 10  # Espacio entre gráficos de silueta
    
    # Se añaden detalles al gráfico.
    plt.title("Gráfico de Silueta para los Clústeres")
    plt.xlabel("Valor del Coeficiente de Silueta")
    plt.ylabel("Clúster")
    
    # Línea vertical para el promedio del score de silueta.
    plt.axvline(x=silhouette_DBSCAN, color="red", linestyle="--")
    plt.text(
        silhouette_DBSCAN + 0.01,
        y_lower / 3,
        f"Promedio: {silhouette_DBSCAN:.3f}",
        color="red",
        fontsize=12,
    )
    
    plt.show()

else:
    # Mensaje de advertencia si no se forman suficientes clústeres.
    print("\nADVERTENCIA: Se encontró menos de 2 clústeres.")
    print("Intente ajustar los parámetros 'eps' y 'min_samples' para mejorar los resultados.")
# Out:
# Número de clústeres encontrados: 2
# Número de puntos de ruido: 282 (de un total de 7563 puntos)
# ------------------------------
# Silhouette Score: 0.044
# Calinski-Harabasz Score: 8.034
# Davies-Bouldin Score: 1.084

# %% [markdown]
# El grafico de silueta muestra la formación de un único gran clúster, el cual tiene un coeficiente de silueta promedio excepcionalmente alto de 0.754. Un valor tan cercano a 1 indica que los puntos dentro de este grupo están altamente cohesionados y bien separados del resto, que probablemente fueron clasificados como ruido.
#
# Este resultado puede interpretarse de dos maneras principales:
# 1. Por un lado, sugiere que la estructura de los datos es la de un único grupo homogéneo, y que no existen subpoblaciones claras y separadas.
# 2. Por otro lado, un resultado como este también podría indicar que la parametrización necesita ajuste pues un hiperparámetro de distancia (eps) demasiado grande podría estar fusionando clústeres que, aunque cercanos, son distintos, llevando a la conclusión errónea de que solo existe un grupo.
#
# Dado este motivo vamos a iterar sobre diferentes combinaciones entre los dos parametros de DBSCAN (Eps y min_samples) con el fin de allar la mejor combinacion que tambien encuentre algun tipo de balance entre los grupos encontrados

# %%
senecafe_reducido.drop(columns=["Cluster_DBSCAN"], inplace=True, errors='ignore') # Quitamos la columna label si existe
senecafe_reducido
# Out:
#           Area  Excentricidad    Medida  FactorForma2  FactorForma4
# 0     0.195173       0.913669  0.210581      0.119457      0.138856
# 1     0.093300       0.336618  0.680331      0.562992      0.789361
# 2     0.149219       0.915580  0.100282      0.155191      0.544239
# 3     0.112213       0.595676  0.597379      0.378319      0.499465
# 4     0.125721       0.595676  0.204208      0.219868      0.657493
# ...        ...            ...       ...           ...           ...
# 7558  0.059048       0.345857  0.599635      0.644393      0.890021
# 7559  0.310174       0.871049  0.770503      0.083034      0.453769
# 7560  0.095931       0.629555  0.336771      0.399244      0.744065
# 7561  0.343430       0.823927  0.715608      0.091056      0.425054
# 7562  0.088868       0.034687  0.584171      0.711089      0.910465
#
# [7563 rows x 5 columns]

# %%
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import numpy as np

# --- CONFIGURACIÓN DEL MODELO ---

# Defino los rangos de búsqueda para los hiperparámetros
eps_range = np.arange(0.1, 0.5, 0.02)
min_samples_range = range(10, 20)

# --- BÚSQUEDA DE HIPERPARÁMETROS ---
results = []
print("Iniciando búsqueda de hiperparámetros...")

for eps in eps_range:
    for min_samples in min_samples_range:
        dbscan = DBSCAN(eps=eps, min_samples=min_samples)
        clusters = dbscan.fit_predict(senecafe_reducido)
        
        mask = clusters != -1
        n_clusters = len(set(clusters[mask]))
        
        # Solo evaluamos si se encontraron al menos 2 clústeres
        if n_clusters >= 2:

            # Si se encuentran 2+ clústeres, procedemos a calcular las métricas
            n_noise = list(clusters).count(-1)
            noise_ratio = n_noise / len(senecafe_reducido)
            
            silhouette = silhouette_score(senecafe_reducido[mask], clusters[mask])
            calinski = calinski_harabasz_score(senecafe_reducido[mask], clusters[mask])
            davies = davies_bouldin_score(senecafe_reducido[mask], clusters[mask])
            
            results.append({
                'eps': eps,
                'min_samples': min_samples,
                'n_clusters': n_clusters,
                'silhouette': silhouette,
                'calinski': calinski,
                'davies': davies,
                'noise_ratio': noise_ratio,
            })

# --- ANÁLISIS DE RESULTADOS ---
if results:
    results_df = pd.DataFrame(results)
    
    scaler = MinMaxScaler()
    metrics_to_scale = ['silhouette', 'calinski', 'davies', 'noise_ratio']
    scaled_metrics = scaler.fit_transform(results_df[metrics_to_scale])
    scaled_df = pd.DataFrame(scaled_metrics, columns=[f"{col}_scaled" for col in metrics_to_scale])
    
    results_df = pd.concat([results_df, scaled_df], axis=1)
    
    # El puntaje de optimización busca maximizar Silhouette y Calinski,
    # y minimizar Davies-Bouldin y la proporción de ruido.
    results_df['optimization_score'] = (
        results_df['silhouette_scaled'] +
        results_df['calinski_scaled'] -
        results_df['davies_scaled'] -
        results_df['noise_ratio_scaled']
    )
    
    best_params = results_df.sort_values(by='optimization_score', ascending=False).iloc[0]
    
    print("\n--- MEJOR COMBINACIÓN DE PARÁMETROS ENCONTRADA ---")
    print(f"Eps: {best_params['eps']:.2f}")
    print(f"Min_samples: {best_params['min_samples']}")
    print(f"Número de clústeres: {best_params['n_clusters']}")
    print(f"Silhouette Score: {best_params['silhouette']:.3f}")
    print(f"Calinski-Harabasz Score: {best_params['calinski']:.3f}")
    print(f"Davies-Bouldin Score: {best_params['davies']:.3f}")
    print(f"Ratio de ruido: {best_params['noise_ratio']:.2%}")
    print("\n--- TOP 10 SOLUCIONES ---")
    display_cols = ['eps', 'min_samples', 'n_clusters', 'silhouette', 'calinski', 'davies', 'noise_ratio', 'optimization_score']
    print(results_df.sort_values(by='optimization_score', ascending=False)[display_cols].head(10))

else:
    print("\nADVERTENCIA: No se encontraron combinaciones de parámetros que produjeran 2 o más clústeres.")
    print("Intenta ampliar el rango de búsqueda de 'eps' y 'min_samples'.")
# Out:
# Iniciando búsqueda de hiperparámetros...
#
# --- MEJOR COMBINACIÓN DE PARÁMETROS ENCONTRADA ---
# Eps: 0.10
# Min_samples: 10.0
# Número de clústeres: 2.0
# Silhouette Score: 0.363
# Calinski-Harabasz Score: 38.254
# Davies-Bouldin Score: 0.517
# Ratio de ruido: 8.71%
#
# --- TOP 10 SOLUCIONES ---
#      eps  min_samples  n_clusters  silhouette    calinski    davies  \
# 0   0.10           10           2    0.362691   38.254494  0.517212
# 7   0.10           18           2    0.332481  842.628824  0.840724
# 8   0.10           19           2    0.336257  841.887614  0.834712
# 10  0.12           19           2    0.177139   52.830538  0.834072
# 1   0.10           11           3    0.087943   36.214426  0.688564
# 2   0.10           12           4    0.027455   39.685551  0.678665
# 9   0.12           10           2    0.044080    8.033633  1.083576
# 6   0.10           17           3    0.004944  436.168288  1.098085
# ...

# %% [markdown]
# Dado estos resultados podemos volver a revisar el modelo con los siguientes hiperparametros.
# - min_samples = 10
# - eps = 0.10

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.metrics import (
    silhouette_score,
    calinski_harabasz_score,
    davies_bouldin_score,
    silhouette_samples, # Faltaba este import en el código original
)

# --- PARÁMETROS DEL MODELO ---
# Se definen los parámetros para el algoritmo DBSCAN.
# Estos valores usualmente se obtienen de un análisis previo (como el método del codo).
min_samples = 10
eps = 0.10

# --- ENTRENAMIENTO DEL MODELO ---
# Se inicializa y entrena el modelo DBSCAN con los datos y parámetros definidos.
dbscan = DBSCAN(eps=eps, min_samples=min_samples)
clusters = dbscan.fit_predict(senecafe_reducido) # Asegúrate de que 'senecafe_reducido' esté definido

# --- ANÁLISIS DE RESULTADOS ---
# Se crea una máscara para excluir los puntos de ruido (etiquetados como -1).
mask = clusters != -1

# Se cuenta el número de clústeres y puntos de ruido.
n_clusters = len(set(clusters[mask]))
n_noise = list(clusters).count(-1)

print(f"Número de clústeres encontrados: {n_clusters}")
print(f"Número de puntos de ruido: {n_noise} (de un total de {len(senecafe_reducido)} puntos)")
print("-" * 30) # Separador para mayor claridad

# --- MÉTRICAS DE EVALUACIÓN ---
# Las métricas de evaluación solo se pueden calcular si hay al menos 2 clústeres.
if n_clusters >= 2:
    # Se calculan las métricas usando solo los datos que pertenecen a un clúster.
    silhouette_DBSCAN = silhouette_score(senecafe_reducido[mask], clusters[mask])
    calinski_DBSCAN = calinski_harabasz_score(senecafe_reducido[mask], clusters[mask])
    davies_DBSCAN = davies_bouldin_score(senecafe_reducido[mask], clusters[mask])
    
    print(f"Silhouette Score: {silhouette_DBSCAN:.3f}")
    print(f"Calinski-Harabasz Score: {calinski_DBSCAN:.3f}")
    print(f"Davies-Bouldin Score: {davies_DBSCAN:.3f}")
    
    # --- VISUALIZACIÓN: GRÁFICO DE SILUETA ---
    labels_clustered = clusters[mask]
    silhouette_vals = silhouette_samples(senecafe_reducido[mask], labels_clustered)
    
    plt.figure(figsize=(10, 6))
    y_lower = 10
    
    for i in range(n_clusters):
        # Se obtienen los valores de silueta para cada clúster.
        ith_cluster_silhouette_values = silhouette_vals[labels_clustered == i]
        ith_cluster_silhouette_values.sort()
        
        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i
        
        # Se asigna un color a cada clúster.
        color = plt.cm.viridis(float(i) / max(n_clusters, 1))
        plt.fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            ith_cluster_silhouette_values,
            facecolor=color,
            edgecolor=color,
            alpha=0.7,
        )
        
        # Se etiqueta cada clúster en el gráfico.
        plt.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
        y_lower = y_upper + 10  # Espacio entre gráficos de silueta
    
    # Se añaden detalles al gráfico.
    plt.title("Gráfico de Silueta para los Clústeres")
    plt.xlabel("Valor del Coeficiente de Silueta")
    plt.ylabel("Clúster")
    
    # Línea vertical para el promedio del score de silueta.
    plt.axvline(x=silhouette_DBSCAN, color="red", linestyle="--")
    plt.text(
        silhouette_DBSCAN + 0.01,
        y_lower / 3,
        f"Promedio: {silhouette_DBSCAN:.3f}",
        color="red",
        fontsize=12,
    )
    
    plt.show()

else:
    # Mensaje de advertencia si no se forman suficientes clústeres.
    print("\nADVERTENCIA: Se encontró menos de 2 clústeres.")
    print("Intente ajustar los parámetros 'eps' y 'min_samples' para mejorar los resultados.")
# Out:
# Número de clústeres encontrados: 2
# Número de puntos de ruido: 659 (de un total de 7563 puntos)
# ------------------------------
# Silhouette Score: 0.363
# Calinski-Harabasz Score: 38.254
# Davies-Bouldin Score: 0.517

# %% [markdown]
# Aun asi encontramos un gran cluster que cubre la mayoria de los datos. Lo que podria apoyar la hipotesis sobre que una division de los datos podria no ser lo mas adecuado dada la naturaleza de los datos. Vamos a revisar en detalle las metricas para ver que nos quieren decir en este caso.

# %% [markdown]
# **Análisis de Métricas de Agrupación**
#
# - **Silhouette Score:**
# Esta métrica mide qué tan bien definidos están los clústeres. Compara la distancia de un punto con los de su propio clúster frente a la distancia con los puntos del clúster más cercano. El valor va de -1 a 1 y se considera bueno entre mas cercano este a 1. Se obtuvo un valor de 0.363. Este es un resultado moderado, que sugiere que existe una estructura de agrupación en los datos, pero los clústeres podrían no estar claramente definidos o podrían tener cierto grado de superposición.
#
# - **Calinski-Harabasz Score:**
# Esta mide la relación entre la dispersión entre los clústeres y la dispersión dentro de cada clúster. El valor va de 0 hacia arriba. Más alto es mejor. Se usa principalmente para comparar diferentes resultados de clustering sobre los mismos datos. (Como haremos mas adelante)
# Este modelo tuvo un valor de 38.254. Por sí solo, este número es difícil de interpretar, pero su principal utilidad es comparar diferentes resultados de clustering sobre los mismos datos, donde un valor más alto indicaría una mejor partición
#
# - **Davies-Bouldin Score:**
# Esta métrica mide la "similitud" promedio de cada clúster con su vecino más cercano, donde la similitud se define por la relación entre el tamaño de los clústeres y la distancia entre ellos. Su valor va de 0 hacia arriba, y a diferencia de las otras métricas, más bajo es mejor. Un puntaje de 0 sería perfecto.
# Se obtuvo un valor de 0.517, lo que indica una separación aceptable entre los clústeres. Sugiere que, aunque no están perfectamente diferenciados, la superposición no es excesiva.

# %% [markdown]
# Ahora veamos la cantidad de registros de granos de café por cada cluster:

# %%
# Cantidad de registros de granos de cafe por cada cluster
senecafe_reducido["Cluster_DBSCAN"] = clusters
print(senecafe_reducido['Cluster_DBSCAN'].value_counts())

# Porcentaje de registros de granos de cafe por cada cluster
total_registros = senecafe_reducido.shape[0]
porcentaje_clusters = senecafe_reducido['Cluster_DBSCAN'].value_counts(normalize=True) * 100
print(porcentaje_clusters)
# Out:
# Cluster_DBSCAN
#  0    6895
# -1     659
#  1       9
# Name: count, dtype: int64
# Cluster_DBSCAN
#  0    91.167526
# -1     8.713473
#  1     0.119000
# Name: proportion, dtype: float64

# %% [markdown]
# Aquí reafirmamos la formación de un clúster principal y altamente dominante (etiquetado como '0'), que concentra a 6,895 puntos, representando el 91.2% del total de los datos. Esto sugiere que la gran mayoría de los datos forman un único grupo denso y homogéneo.
#
# Por otro lado, el algoritmo ha identificado 659 puntos (8.7%) como ruido (etiqueta '-1'), considerándolos atípicos o aislados de las zonas de alta densidad.
#
# Adicionalmente, se ha detectado un único clúster muy pequeño y minoritario (etiquetado como '1'), que contiene solo 9 puntos, representando apenas el 0.1% del total.
#
# Esta distribución de clústeres es extremadamente desbalanceada y muestra que, con los parámetros utilizados, el conjunto de datos se comporta mayoritariamente como una sola agrupación compacta con algunos outliers dispersos.

# %% [markdown]
# **Comportamiento en parejas de atributos por cluster**

# %%
senecafe_reducido_DBSCAN = senecafe_reducido

sns.pairplot(senecafe_reducido_DBSCAN, hue="Cluster_DBSCAN", palette="tab10")
plt.suptitle("Comportamiento en parejas de atributos por cluster")
plt.tight_layout()
plt.show()

# %% [markdown]
# El gráfico de pares confirma visualmente los resultados de DBSCAN, revelando los siguientes puntos clave:
#
# - Clúster Dominante: Existe un único clúster masivo (Clúster 0, naranja) que forma un núcleo denso y central, agrupando la gran mayoría de los datos (91%).
#
# - Ruido como Outliers: Los puntos de ruido (Clúster -1, azul) se ubican claramente en la periferia de la distribución principal, confirmando que son outliers o anomalías.
#
# **Conclusión:** La visualización demuestra que DBSCAN actuó realmente como un detector de anomalías, separando un núcleo de datos homogéneo de sus valores atípicos, en lugar de segmentar el conjunto en múltiples grupos.

# %% [markdown]
# **Conclusiones**
# - La implementación del algoritmo DBSCAN fue exitosa en la caracterización de la estructura de los datos, al identificar un único clúster principal y dominante. La gran fortaleza del método en este caso fue su capacidad para aislar un conjunto de granos atípicos (ruido) en lugar de forzar una segmentación artificial.
#
# - Dado que se encontró un solo clúster principal, las métricas de evaluación como el Coeficiente de Silueta o el Índice de Davies-Bouldin no son aplicables, ya que requieren al menos dos clústeres para medir la separación. La validez del resultado no reside en la calidad de la separación, sino en la correcta identificación de un núcleo de datos homogéneo.
#
# - La capacidad del modelo para identificar aproximadamente un 8% de los datos como ruido es un resultado de gran valor. Esto previene que los valores atípicos distorsionen el perfil del grupo principal y permite definir un clúster más puro y verdaderamente representativo del patrón morfológico predominante en la muestra.
#
# - Finalmente, el resultado no son dos clústeres balanceados, sino un único clúster masivo que demuestra la alta homogeneidad de la muestra. Esto ofrece a SenecaféAlpes una base de alta confianza para establecer un perfil estándar o "ideal" de sus granos. Más que para comparar variedades, este modelo es una herramienta poderosa para el control de calidad, permitiendo detectar automáticamente cualquier desviación o anomalía respecto a la norma establecida.

# %% [markdown]
# ### 7.4. Análisis de Resultados

# %% [markdown]
# Para evaluar y comparar el rendimiento de los tres algoritmos de agrupación implementados (K-Means, GMM y DBSCAN), se utilizaron tres métricas internas clave: el Coeficiente de Silueta, el Índice de Calinski-Harabasz y el Índice de Davies-Bouldin.
#
# Tabla Comparativa de Métricas
# A continuación, se presenta una tabla que resume el rendimiento de cada modelo. Para K-Means y GMM se muestran los resultados con 2 clústeres, que fue la configuración óptima encontrada. Para DBSCAN, se utilizan los resultados de la configuración optimizada mediante la seleccion de sus parametros respectivos

# %%
# Imprimos metricas de los tres modelos para compararlos
print("Métricas de KMeans (k=2):")
print("Silhouette Score:", silhouette_avg_KN)
print("Calinski-Harabasz Score:", calinski_KN)
print("Davies-Bouldin Score:", davies_KN)

print("\nMétricas de GMM (n=2):")
print("Silhouette Score:", silhouette_avg_GMM)
print("Calinski-Harabasz Score:", calinski_GMM)
print("Davies-Bouldin Score:", davies_GMM)

print("\nMétricas de DBSCAN:")
print("Silhouette Score:", silhouette_DBSCAN)
print("Calinski-Harabasz Score:", calinski_DBSCAN)
print("Davies-Bouldin Score:", davies_DBSCAN)
# Out:
# Métricas de KMeans (k=2):
# Silhouette Score: 0.3202094762611336
# Calinski-Harabasz Score: 4467.46676861266
# Davies-Bouldin Score: 1.2306488002345262
#
# Métricas de GMM (n=2):
# Silhouette Score: 0.20163280726740693
# Calinski-Harabasz Score: 2111.854524420442
# Davies-Bouldin Score: 1.7672211777527298
#
# Métricas de DBSCAN:
# Silhouette Score: 0.36269076432043806
# Calinski-Harabasz Score: 38.25449428969385
# Davies-Bouldin Score: 0.5172123214779477

# %% [markdown]
# El modelo DBSCAN es el que muestra la mejor calidad de clúster en dos de las tres métricas, mientras que GMM resulta ser el menos adecuado. DBSCAN obtiene el Silhouette Score más alto (0.363) y el mejor (más bajo) Davies-Bouldin Score (0.517). Esto indica que la agrupación que encuentra es la que tiene la mejor definición y separación.
#
# Por otro lado, K-Means obtiene un Silhouette Score aceptable de 0.320, pero destaca en el Calinski-Harabasz Score con un valor de 4467.5, muy superior a los otros modelos. Esto sugiere que K-Means fue efectivo en crear dos clústeres compactos y bien diferenciados entre sí.
#
# La aparente contradicción se explica por la metodología de DBSCAN: su alto rendimiento no se debe a que encuentre dos grupos balanceados, sino a que su enfoque basado en densidad le permite identificar un único clúster cohesivo y descartar el resto como ruido, capturando la morfología de los datos de forma más natural.
#
# Finalmente, el modelo GMM mostró el peor desempeño en todas las métricas, lo que sugiere que la flexibilidad de sus clústeres elipsoidales no se ajustó a la distribución real de los datos.

# %% [markdown]
# **Analisis Conjunto**
#
# El modelo DBSCAN presenta los mejores indicadores de calidad de clúster, seguido de cerca por KMeans. El modelo GMM muestra el rendimiento más bajo.
#
# Sin embargo, la elección final depende crucialmente de la interpretación del resultado de DBSCAN y del objetivo del análisis. A continuación se desglosa el rendimiento de cada modelo:
#
# - **KMeans:**
# Ofrece una segmentación coherente y balanceada. El altísimo score de Calinski-Harabasz (4467.5) sugiere que los dos clústeres que crea son densos y están bien separados entre sí. Es un modelo robusto y una opción muy viable si el objetivo es forzar una división en dos grupos.
#
#
# - **GMM:**
# Este es el modelo con el rendimiento más bajo. Sus métricas son inferiores en los indicadores clave de Silhouette y Davies-Bouldin, lo que sugiere que sus clústeres elipsoidales no se ajustan bien a la forma de los datos. Este modelo debería ser descartado.
#
# - **DBSCAN:**
# Este modelo no forzó los datos a dividirse en dos grupos. En su lugar, concluyó que la estructura natural es un gran grupo de alta densidad con puntos atípicos o "ruido". La calidad de esta agrupación, según las métricas de Silhouette (0.363) y Davies-Bouldin (0.517), es la mejor de la comparativa, lo que valida su enfoque basado en densidad como una representación fiel de la estructura intrínseca de los datos.

# %% [markdown]
# Vamos a analizar un poco más a detalle los resultados obtenidos

# %%
# Eliminar el ruido (-1) para análisis estadístico
senecafe_reducido_DBSCAN = senecafe_reducido_DBSCAN[senecafe_reducido_DBSCAN['Cluster_DBSCAN'] != -1]

# Calcular estadísticas descriptivas por cluster
cluster_stats = senecafe_reducido_DBSCAN.groupby('Cluster_DBSCAN').describe()

display(cluster_stats)

# Visualizar las medias de cada variable por cluster
plt.figure(figsize=(12, 8))
means_by_cluster = senecafe_reducido_DBSCAN.groupby('Cluster_DBSCAN').mean()

means_by_cluster.T.plot(kind='bar', figsize=(14, 7))
plt.title('Valores Medios de Variables por Cluster (DBSCAN)')
plt.ylabel('Mean Value')
plt.xlabel('Feature')
plt.xticks(rotation=45)
plt.legend(title='Cluster')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
#                   Area                                                    \
#                  count      mean       std       min       25%       50%
# Cluster_DBSCAN
# 0               6895.0  0.123666  0.075172  0.000217  0.070274  0.104721
# 1                  9.0  0.179783  0.029924  0.139797  0.158892  0.172243
#
#                                    Excentricidad            ... FactorForma2  \
#                      75%       max         count      mean  ...          75%
# Cluster_DBSCAN                                              ...
# 0               0.153281  0.422693        6895.0  0.564022  ...     0.548100
# 1               0.192133  0.234257           9.0  0.948926  ...     0.118723
#
#                          FactorForma4                                          \
#                      max        count      mean       std       min       25%
# Cluster_DBSCAN
# 0               0.887053       6895.0  0.665592  0.198130  0.000000  0.568319
# ...

# %% [markdown]
# El gráfico de valores medios por clúster permite caracterizar el perfil de los grupos identificados por DBSCAN, utilizando al Clúster 0 (azul) como el perfil de referencia o estándar, dado que representa a la inmensa mayoría de la muestra.
#
# El gráfico muestra que el clúster secundario, aunque muy pequeño, posee características morfológicas únicas y extremas que lo diferencian claramente del grupo principal.
#
# Específicamente, el Clúster 1 (naranja) destaca por tener valores notablemente más altos en 'Excentricidad' y 'Medida'. En contraste, este mismo clúster presenta valores mucho más bajos en 'FactorForma2' y 'FactorForma4' en comparación con el clúster dominante.
#
# El gráfico confirma la homogeneidad general de la muestra (representada por el Clúster 0), pero también caracteriza con éxito el pequeño nicho de datos (Clúster 1) que se desvía de la norma con un perfil muy específico.

# %% [markdown]
# **Conclusión Final y Recomendación**
#
# Tras el análisis comparativo, la recomendación final se inclina de manera concluyente por el modelo DBSCAN, no solo por la superioridad de sus métricas de calidad (Silhouette y Davies-Bouldin), sino por la relevancia de sus hallazgos.
#
# El resultado más revelador del análisis no es una segmentación en dos grupos, sino la identificación de un único clúster masivo y extremadamente cohesivo. En lugar de ser una limitación, esto demuestra la alta homogeneidad de la muestra, un hallazgo de gran valor para SenecaféAlpes. Esta uniformidad proporciona una base empírica de alta confianza para establecer un perfil estándar o "ideal" de sus granos de café.
#
# Aun asi, es importante mencionar el escenario en que K-Means sería la elección adecuada. Si el objetivo de negocio de SenecaféAlpes requiriera obligatoriamente segmentar la totalidad de la producción en dos categorías distintas —por ejemplo, para crear una línea "Estándar" y otra "Selecta"— sin posibilidad de dejar granos sin clasificar, entonces el modelo K-Means sería la herramienta más adecuada. Aunque esta división sería una estructura "forzada" y menos natural que la detectada por DBSCAN, cumpliría con el requisito operativo de una clasificación exhaustiva de todos los elementos.
#
# Finalmente, el modelo de este ejercicio trasciende su función como herramienta de segmentación para convertirse en un sistema de control de calidad. Su aplicación principal no sería comparar distintas variedades, sino validar que los nuevos lotes se ajustan a la norma establecida, permitiendo detectar automáticamente cualquier grano que presente una desviación o anomalía (el "ruido" identificado por el modelo) respecto a este perfil estándar. Por lo tanto, se recomienda adoptar el modelo DBSCAN como un mecanismo robusto para asegurar la consistencia y la calidad del producto.
#
# Consideramos esto un resultado adecuado y acorde a los objetivos generales del negocio que recordamos son:
# - Control de Calidad: Estandarizar la selección y clasificación.
# - Optimización de Mercado: Diseñar nuevas mezclas de valor.
# - Innovación en Trazabilidad: Automatizar la identificación de variedades.
#
# Nuestra nueva herramienta va en virtud del proposito de Control de Calidad de la empresa.

# %% [markdown]
# ## 8. Uso de IA
#
# ### Ana María Hernández Lasso
# Para este taller, se hizo uso del modelo ChatGPT 5 de la siguiente forma:
#
# - Apoyo puntual en código (estructuración de ciclos para probar distintos k, o para corrección de errores en la ejecución).
# - Mejorar la redacción puntual de frases para tener un tono más académico en algunas de ellas.
#
# ### Juan Sebastián Ardila López
#
# Para este taller, se hizo uso del modelo Gemini 2.5 Pro de la siguiente forma:
#
# - Se consultaron alternativas de algoritmos de clasificación, con esto, descubrí el algoritmo GMM.
# - Se consultaron fuentes para implementar el algoritmo, lo cual llevó a la documentación de GaussianMixture en Sklearn
# - Se utilizó Gemini para hacer debug de un pequeño error con el que se contaba en la ejecución
#
# ### William Andrés Bayona Vergara
# Se utilizo el modelo Gemini 2.5 Pro de la siguiente manera:
#
# - Asistencia en la comprensión teórica del algoritmo DBSCAN y sus hiperparámetros (eps, min_samples)
# - Formateo de fragmentos de código en Python para mejor presentación
# - Apoyo en la interpretación de los resultados del modelo, incluyendo las métricas de evaluación
# - Generacion de la imagen comparativa entre los dos tipos de granos identificados
